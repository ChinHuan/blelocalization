# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width: 98%!important}</style>"))
# Out:
# <style>.container {width: 98%!important}</style>

# %%
import os
import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %%
scanners = [
    'C400A2E19293', # R1824
    'CD4533FFC0E1', # R1836
    'D2B6503554D7', # R1826
    'DB8B36A69C56', # R1840
    'DD697EA75B68', # R1835
    'DF231643E227', # R1830
    'E13B805C6CB0', # R1825
    'E43355CA8B96', # R1833
    'E6D9D20DD197', # R1831
    'E8FD0B453DC4', # R1837
    'E96AF2C858BA', # R1827
    'EC72840D9AD3', # R1823
    'F1307ECB3B90', # R1834
    'F1EDAF28E08A', # R1821
    'F69A86823B96', # R1828
    'FB2EE01C18CE', # R1829
    'FDAE5980F28C'  # R1832
]

# %%
rawData = pd.read_csv("../Data/rssi3.csv")
rawData.drop("name", axis=1, inplace=True)

# %%
rawData
# Out:
#                       time        beacon location  rssi       scanner
# 0      1575248732956000000  0117C55D14E4    V1_32   -96  E43355CA8B96
# 1      1575248732976000000  0117C55D14E4    V1_32   -82  F1307ECB3B90
# 2      1575248733015000000  0117C55D14E4    V1_32   -72  E6D9D20DD197
# 3      1575248733034000000  0117C55D14E4    V1_32   -79  F1307ECB3B90
# 4      1575248733096000000  0117C55D14E4    V1_32   -68  FB2EE01C18CE
# ...                    ...           ...      ...   ...           ...
# 26542  1575362605486000000  0117C55D14E4    V1_31   -74  FB2EE01C18CE
# 26543  1575362605549000000  0117C55D14E4    V1_31   -79  E6D9D20DD197
# 26544  1575362605552000000  0117C55D14E4    V1_31   -85  EC72840D9AD3
# 26545  1575362605554000000  0117C55D14E4    V1_31   -71  E6D9D20DD197
# 26546  1575362605560000000  0117C55D14E4    V1_31   -73  E6D9D20DD197
#
# [26547 rows x 5 columns]

# %%
B1 = rawData[rawData["beacon"] == "0117C55D14E4"]
B1
# Out:
#                       time        beacon location  rssi       scanner
# 0      1575248732956000000  0117C55D14E4    V1_32   -96  E43355CA8B96
# 1      1575248732976000000  0117C55D14E4    V1_32   -82  F1307ECB3B90
# 2      1575248733015000000  0117C55D14E4    V1_32   -72  E6D9D20DD197
# 3      1575248733034000000  0117C55D14E4    V1_32   -79  F1307ECB3B90
# 4      1575248733096000000  0117C55D14E4    V1_32   -68  FB2EE01C18CE
# ...                    ...           ...      ...   ...           ...
# 26542  1575362605486000000  0117C55D14E4    V1_31   -74  FB2EE01C18CE
# 26543  1575362605549000000  0117C55D14E4    V1_31   -79  E6D9D20DD197
# 26544  1575362605552000000  0117C55D14E4    V1_31   -85  EC72840D9AD3
# 26545  1575362605554000000  0117C55D14E4    V1_31   -71  E6D9D20DD197
# 26546  1575362605560000000  0117C55D14E4    V1_31   -73  E6D9D20DD197
#
# [26547 rows x 5 columns]

# %%
B1 = B1.pivot_table(columns="scanner", values="rssi", index=["time", "location"]).rename_axis(None, axis=1).reset_index()

# %%
B1["time"] = pd.to_datetime(B1["time"])
B1
# Out:
#                          time location  C400A2E19293  CD4533FFC0E1  \
# 0     2019-12-02 01:05:32.956    V1_32           NaN           NaN
# 1     2019-12-02 01:05:32.976    V1_32           NaN           NaN
# 2     2019-12-02 01:05:33.015    V1_32           NaN           NaN
# 3     2019-12-02 01:05:33.034    V1_32           NaN           NaN
# 4     2019-12-02 01:05:33.096    V1_32           NaN           NaN
# ...                       ...      ...           ...           ...
# 24299 2019-12-03 08:43:25.486    V1_31           NaN           NaN
# 24300 2019-12-03 08:43:25.549    V1_31           NaN           NaN
# 24301 2019-12-03 08:43:25.552    V1_31           NaN           NaN
# 24302 2019-12-03 08:43:25.554    V1_31           NaN           NaN
# 24303 2019-12-03 08:43:25.560    V1_31           NaN           NaN
#
#        D2B6503554D7  DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 24299           NaN           NaN           NaN           NaN           NaN
# 24300           NaN           NaN           NaN           NaN           NaN
# 24301           NaN           NaN           NaN           NaN           NaN
# 24302           NaN           NaN           NaN           NaN           NaN
# 24303           NaN           NaN           NaN           NaN           NaN
#
#        E43355CA8B96  E6D9D20DD197  E8FD0B453DC4  E96AF2C858BA  EC72840D9AD3  \
# 0             -96.0           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN         -72.0           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 24299           NaN           NaN           NaN           NaN           NaN
# 24300           NaN         -79.0           NaN           NaN           NaN
# 24301           NaN           NaN           NaN           NaN         -85.0
# 24302           NaN         -71.0           NaN           NaN           NaN
# 24303           NaN         -73.0           NaN           NaN           NaN
#
#        F1307ECB3B90  F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  FDAE5980F28C
# 0               NaN           NaN           NaN           NaN           NaN
# 1             -82.0           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3             -79.0           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN         -68.0           NaN
# ...             ...           ...           ...           ...           ...
# 24299           NaN           NaN           NaN         -74.0           NaN
# 24300           NaN           NaN           NaN           NaN           NaN
# 24301           NaN           NaN           NaN           NaN           NaN
# 24302           NaN           NaN           NaN           NaN           NaN
# 24303           NaN           NaN           NaN           NaN           NaN
#
# [24304 rows x 19 columns]

# %%
pinData = pd.read_csv("../Documents/Pin", sep='\t')
pinData
# Out:
#        Id          X         Y
# 0    V1_1  10.747900   2.29302
# 1   V1_10  11.176600   5.29753
# 2   V1_11  14.063600   5.31235
# 3   V1_12  17.173201   5.21713
# 4   V1_13  20.171700   5.12133
# 5   V1_14  23.169100   5.24792
# 6   V1_15  26.167101   5.26332
# 7   V1_16  29.054100   5.27814
# 8   V1_17   2.278330   8.25413
# 9   V1_18   6.164600   8.27409
# 10  V1_19  10.162500   8.18342
# 11   V1_2  13.634900   2.30785
# 12  V1_20  14.159800   8.20395
# 13  V1_21  18.712299   8.22733
# 14  V1_22  23.153700   8.25014
# 15  V1_23  27.151600   8.15948
# 16  V1_24  29.594400   8.17202
# 17  V1_25   2.268050  10.25560
# 18  V1_26   6.255650  12.16640
# 19  V1_27  10.141900  12.18640
# 20  V1_28  14.250300  12.20750
# 21  V1_29  18.691700  12.23030
# 22   V1_3  16.633400   2.21205
# 23  V1_30  23.244200  12.25370
# 24  V1_31  27.133301  11.71770
# 25  V1_32  29.689400  11.28600
# 26  V1_33  31.693199  10.29550
# 27  V1_34  10.242100  14.29960
# 28  V1_35   2.141600  13.25730
# 29  V1_36   5.689620  14.27630
# 30  V1_37  25.676701  14.26770
# 31  V1_38  14.683600  14.32240
# 32  V1_39  19.569201  14.34750
# 33   V1_4  19.631399   2.22745
# 34  V1_40  22.678699  14.25230
# 35  V1_41  29.674601  14.17700
# 36  V1_42   5.196110   2.26451
# 37  V1_43   8.194090   2.27991
# 38   V1_5  26.182501   2.26109
# 39   V1_6  29.180500   2.27649
# 40   V1_7   2.293750   5.25191
# 41   V1_8   5.180690   5.26673
# 42   V1_9   8.178670   5.28213

# %%
pinDataMap = pinData.set_index("Id").transpose()
toCoor = pinDataMap.to_dict()

# %%
B1["X"] = B1["location"].apply(lambda x: toCoor[x]["X"])
B1["Y"] = B1["location"].apply(lambda x: toCoor[x]["Y"])
B1.drop("location", axis=1, inplace=True)

# %%
train = B1.sample(frac=0.8,random_state=0)
test = B1.drop(train.index)

# %%
train
# Out:
#                          time  C400A2E19293  CD4533FFC0E1  D2B6503554D7  \
# 1620  2019-12-02 01:14:29.062           NaN           NaN           NaN
# 21995 2019-12-03 08:27:32.489           NaN           NaN           NaN
# 6721  2019-12-02 01:34:52.202           NaN           NaN           NaN
# 17797 2019-12-03 08:17:48.692           NaN           NaN           NaN
# 7260  2019-12-02 01:35:19.120           NaN           NaN           NaN
# ...                       ...           ...           ...           ...
# 11903 2019-12-02 01:54:00.444           NaN           NaN           NaN
# 17632 2019-12-03 08:17:37.715           NaN           NaN           NaN
# 21650 2019-12-03 08:27:11.036           NaN           NaN           NaN
# 11608 2019-12-02 01:53:46.752           NaN           NaN           NaN
# 13412 2019-12-03 08:07:40.243           NaN           NaN           NaN
#
#        DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  E43355CA8B96  \
# 1620            NaN           NaN         -70.0           NaN           NaN
# 21995           NaN           NaN           NaN         -87.0           NaN
# 6721            NaN           NaN           NaN           NaN           NaN
# 17797           NaN           NaN           NaN           NaN           NaN
# 7260            NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 11903           NaN           NaN           NaN           NaN           NaN
# 17632           NaN           NaN           NaN           NaN           NaN
# 21650           NaN           NaN         -93.0           NaN           NaN
# 11608           NaN           NaN           NaN           NaN           NaN
# 13412           NaN           NaN           NaN         -61.0           NaN
#
#        E6D9D20DD197  E8FD0B453DC4  E96AF2C858BA  EC72840D9AD3  F1307ECB3B90  \
# 1620            NaN           NaN           NaN           NaN           NaN
# 21995           NaN           NaN           NaN           NaN           NaN
# 6721          -77.0           NaN           NaN           NaN           NaN
# 17797           NaN           NaN           NaN           NaN           NaN
# 7260            NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 11903           NaN           NaN           NaN           NaN         -75.0
# 17632           NaN           NaN           NaN           NaN           NaN
# 21650           NaN           NaN           NaN           NaN           NaN
# 11608           NaN           NaN           NaN           NaN           NaN
# 13412           NaN           NaN           NaN           NaN           NaN
#
#        F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  FDAE5980F28C          X  \
# 1620            NaN           NaN           NaN           NaN  23.153700
# 21995           NaN           NaN           NaN           NaN  29.689400
# 6721            NaN           NaN           NaN           NaN  18.712299
# 17797           NaN           NaN         -89.0           NaN  18.691700
# 7260          -88.0           NaN           NaN           NaN  18.712299
# ...             ...           ...           ...           ...        ...
# 11903           NaN           NaN           NaN           NaN  27.151600
# 17632           NaN           NaN         -82.0           NaN  18.691700
# 21650           NaN           NaN           NaN           NaN  29.689400
# 11608           NaN           NaN         -75.0           NaN  27.151600
# 13412           NaN           NaN           NaN           NaN  23.169100
#
#               Y
# 1620    8.25014
# 21995  11.28600
# 6721    8.22733
# 17797  12.23030
# 7260    8.22733
# ...         ...
# 11903   8.15948
# 17632  12.23030
# 21650  11.28600
# 11608   8.15948
# 13412   5.24792
#
# [19443 rows x 20 columns]

# %%
train.set_index("time", inplace=True)
train_rolled = train.groupby(["X", "Y"])[scanners].rolling(20, min_periods=1).mean().reset_index()
train_rolled
# Out:
#                X         Y                    time  C400A2E19293  \
# 0      17.173201   5.21713 2019-12-03 08:13:43.852           NaN
# 1      17.173201   5.21713 2019-12-02 01:30:04.260           NaN
# 2      17.173201   5.21713 2019-12-03 08:13:52.645         -77.0
# 3      17.173201   5.21713 2019-12-03 08:13:05.244         -77.0
# 4      17.173201   5.21713 2019-12-02 01:30:58.042         -77.0
# ...          ...       ...                     ...           ...
# 19438  29.689400  11.28600 2019-12-02 01:05:35.169         -94.0
# 19439  29.689400  11.28600 2019-12-03 08:27:12.192         -94.0
# 19440  29.689400  11.28600 2019-12-02 01:06:22.692         -94.0
# 19441  29.689400  11.28600 2019-12-02 01:06:22.466         -94.0
# 19442  29.689400  11.28600 2019-12-03 08:27:11.036         -94.0
#
#        CD4533FFC0E1  D2B6503554D7  DB8B36A69C56  DD697EA75B68  DF231643E227  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN        -81.00
# 4             -65.0           NaN           NaN           NaN        -81.00
# ...             ...           ...           ...           ...           ...
# 19438           NaN         -84.0           NaN         -88.0        -68.40
# 19439           NaN         -84.0           NaN         -88.0        -68.40
# 19440           NaN         -84.0           NaN         -88.0        -68.40
# 19441           NaN         -84.0           NaN         -88.0        -66.75
# 19442           NaN         -84.0           NaN         -88.0        -73.25
#
#        E13B805C6CB0  E43355CA8B96  E6D9D20DD197  E8FD0B453DC4  E96AF2C858BA  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 19438         -80.0           NaN        -69.50           NaN         -63.5
# 19439         -80.0           NaN        -70.00           NaN         -63.5
# 19440         -80.0           NaN        -70.00           NaN         -63.5
# 19441         -80.0           NaN        -71.25           NaN         -63.5
# 19442         -80.0           NaN        -71.25           NaN         -63.5
#
#        EC72840D9AD3  F1307ECB3B90  F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  \
# 0               NaN           NaN           NaN           NaN    -85.000000
# 1             -56.0           NaN           NaN           NaN    -85.000000
# 2             -56.0           NaN           NaN           NaN    -85.000000
# 3             -56.0           NaN           NaN           NaN    -85.000000
# 4             -56.0           NaN           NaN           NaN    -85.000000
# ...             ...           ...           ...           ...           ...
# 19438         -77.0         -82.0           NaN           NaN    -74.666667
# 19439         -77.0         -82.0           NaN         -82.0    -74.666667
# 19440         -77.0         -82.0           NaN         -82.0    -71.000000
# 19441         -77.0         -82.0           NaN         -82.0    -71.000000
# 19442         -77.0         -82.0           NaN         -82.0    -71.000000
#
#        FDAE5980F28C
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 19438         -88.0
# 19439         -88.0
# 19440         -88.0
# 19441         -88.0
# 19442         -88.0
#
# [19443 rows x 20 columns]

# %%
V1 = train_rolled[(train_rolled['X'] == 27.151600) & (train_rolled['Y'] == 8.15948)]
plt.plot(np.arange(V1.shape[0]), V1['DF231643E227'])
plt.show()

# %%
train_rolled.update(train_rolled.groupby(["X", "Y"])[scanners].ffill().fillna(-95))
train_rolled.drop("time", axis=1, inplace=True)

# %%
test.set_index("time", inplace=True)
test_rolled = test.groupby(["X", "Y"])[scanners].rolling(20, min_periods=1).mean().reset_index()

# %%
test_rolled.update(test_rolled.groupby(["X", "Y"])[scanners].ffill().fillna(-95))
test_rolled.drop("time", axis=1, inplace=True)

# %%
train_rolled
# Out:
#                X         Y  C400A2E19293  CD4533FFC0E1  D2B6503554D7  \
# 0      17.173201   5.21713         -95.0         -95.0         -95.0
# 1      17.173201   5.21713         -95.0         -95.0         -95.0
# 2      17.173201   5.21713         -77.0         -95.0         -95.0
# 3      17.173201   5.21713         -77.0         -95.0         -95.0
# 4      17.173201   5.21713         -77.0         -65.0         -95.0
# ...          ...       ...           ...           ...           ...
# 19438  29.689400  11.28600         -94.0         -79.0         -84.0
# 19439  29.689400  11.28600         -94.0         -79.0         -84.0
# 19440  29.689400  11.28600         -94.0         -79.0         -84.0
# 19441  29.689400  11.28600         -94.0         -79.0         -84.0
# 19442  29.689400  11.28600         -94.0         -79.0         -84.0
#
#        DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  E43355CA8B96  \
# 0             -95.0         -95.0        -95.00         -95.0         -95.0
# 1             -95.0         -95.0        -95.00         -95.0         -95.0
# 2             -95.0         -95.0        -95.00         -95.0         -95.0
# 3             -95.0         -95.0        -81.00         -95.0         -95.0
# 4             -95.0         -95.0        -81.00         -95.0         -95.0
# ...             ...           ...           ...           ...           ...
# 19438         -87.0         -88.0        -68.40         -80.0         -90.0
# 19439         -87.0         -88.0        -68.40         -80.0         -90.0
# 19440         -87.0         -88.0        -68.40         -80.0         -90.0
# 19441         -87.0         -88.0        -66.75         -80.0         -90.0
# 19442         -87.0         -88.0        -73.25         -80.0         -90.0
#
#        E6D9D20DD197  E8FD0B453DC4  E96AF2C858BA  EC72840D9AD3  F1307ECB3B90  \
# 0            -95.00         -95.0         -95.0         -95.0         -95.0
# 1            -95.00         -95.0         -95.0         -56.0         -95.0
# 2            -95.00         -95.0         -95.0         -56.0         -95.0
# 3            -95.00         -95.0         -95.0         -56.0         -95.0
# 4            -95.00         -95.0         -95.0         -56.0         -95.0
# ...             ...           ...           ...           ...           ...
# 19438        -69.50         -96.0         -63.5         -77.0         -82.0
# 19439        -70.00         -96.0         -63.5         -77.0         -82.0
# 19440        -70.00         -96.0         -63.5         -77.0         -82.0
# 19441        -71.25         -96.0         -63.5         -77.0         -82.0
# 19442        -71.25         -96.0         -63.5         -77.0         -82.0
#
#        F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  FDAE5980F28C
# 0             -95.0         -95.0    -85.000000         -95.0
# 1             -95.0         -95.0    -85.000000         -95.0
# 2             -95.0         -95.0    -85.000000         -95.0
# 3             -95.0         -95.0    -85.000000         -95.0
# 4             -95.0         -95.0    -85.000000         -95.0
# ...             ...           ...           ...           ...
# 19438         -94.0         -83.0    -74.666667         -88.0
# 19439         -94.0         -82.0    -74.666667         -88.0
# 19440         -94.0         -82.0    -71.000000         -88.0
# 19441         -94.0         -82.0    -71.000000         -88.0
# 19442         -94.0         -82.0    -71.000000         -88.0
#
# [19443 rows x 19 columns]

# %%
X_train = train_rolled.iloc[:, 2:]
y_train = train_rolled.iloc[:, :2]

X_test = test_rolled.iloc[:, 2:]
y_test = test_rolled.iloc[:, :2]

# %%
X_train
# Out:
#        C400A2E19293  CD4533FFC0E1  D2B6503554D7  DB8B36A69C56  DD697EA75B68  \
# 0             -95.0         -95.0         -95.0         -95.0         -95.0
# 1             -95.0         -95.0         -95.0         -95.0         -95.0
# 2             -77.0         -95.0         -95.0         -95.0         -95.0
# 3             -77.0         -95.0         -95.0         -95.0         -95.0
# 4             -77.0         -65.0         -95.0         -95.0         -95.0
# ...             ...           ...           ...           ...           ...
# 19438         -94.0         -79.0         -84.0         -87.0         -88.0
# 19439         -94.0         -79.0         -84.0         -87.0         -88.0
# 19440         -94.0         -79.0         -84.0         -87.0         -88.0
# 19441         -94.0         -79.0         -84.0         -87.0         -88.0
# 19442         -94.0         -79.0         -84.0         -87.0         -88.0
#
#        DF231643E227  E13B805C6CB0  E43355CA8B96  E6D9D20DD197  E8FD0B453DC4  \
# 0            -95.00         -95.0         -95.0        -95.00         -95.0
# 1            -95.00         -95.0         -95.0        -95.00         -95.0
# 2            -95.00         -95.0         -95.0        -95.00         -95.0
# 3            -81.00         -95.0         -95.0        -95.00         -95.0
# 4            -81.00         -95.0         -95.0        -95.00         -95.0
# ...             ...           ...           ...           ...           ...
# 19438        -68.40         -80.0         -90.0        -69.50         -96.0
# 19439        -68.40         -80.0         -90.0        -70.00         -96.0
# 19440        -68.40         -80.0         -90.0        -70.00         -96.0
# 19441        -66.75         -80.0         -90.0        -71.25         -96.0
# 19442        -73.25         -80.0         -90.0        -71.25         -96.0
#
#        E96AF2C858BA  EC72840D9AD3  F1307ECB3B90  F1EDAF28E08A  F69A86823B96  \
# 0             -95.0         -95.0         -95.0         -95.0         -95.0
# 1             -95.0         -56.0         -95.0         -95.0         -95.0
# 2             -95.0         -56.0         -95.0         -95.0         -95.0
# 3             -95.0         -56.0         -95.0         -95.0         -95.0
# 4             -95.0         -56.0         -95.0         -95.0         -95.0
# ...             ...           ...           ...           ...           ...
# 19438         -63.5         -77.0         -82.0         -94.0         -83.0
# 19439         -63.5         -77.0         -82.0         -94.0         -82.0
# 19440         -63.5         -77.0         -82.0         -94.0         -82.0
# 19441         -63.5         -77.0         -82.0         -94.0         -82.0
# 19442         -63.5         -77.0         -82.0         -94.0         -82.0
#
#        FB2EE01C18CE  FDAE5980F28C
# 0        -85.000000         -95.0
# 1        -85.000000         -95.0
# 2        -85.000000         -95.0
# 3        -85.000000         -95.0
# 4        -85.000000         -95.0
# ...             ...           ...
# 19438    -74.666667         -88.0
# 19439    -74.666667         -88.0
# 19440    -71.000000         -88.0
# 19441    -71.000000         -88.0
# 19442    -71.000000         -88.0
#
# [19443 rows x 17 columns]

# %%
model = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=[17]),
    layers.Dense(2)
])

optimizer = tf.keras.optimizers.RMSprop(0.001)
model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                576
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 642
# Trainable params: 642
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 500

checkpoint_path = "../Models/rolling_nn2/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, 
                    epochs=EPOCHS, validation_split=0.2, 
                    verbose=0, callbacks=[early_stop, tfdocs.modeling.EpochDots(), cp_callback])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# Epoch: 0, loss:84.6036,  mae:4.4383,  mse:84.6036,  val_loss:22.2039,  val_mae:3.9647,  val_mse:22.2039,
# .
# Epoch 00001: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00002: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00003: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00004: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00005: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00006: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00007: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00008: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00009: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00010: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00011: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00012: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00013: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00014: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00015: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00016: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00017: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00018: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00019: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00020: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00021: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00022: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00023: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00024: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00025: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00026: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00027: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00028: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00029: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00030: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00031: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00032: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00033: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00034: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00035: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00036: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00037: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00038: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00039: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00040: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00041: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00042: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00043: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00044: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00045: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00046: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00047: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00048: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00049: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00050: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00051: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00052: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00053: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00054: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00055: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00056: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00057: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00058: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00059: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00060: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00061: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00062: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00063: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00064: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00065: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00066: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00067: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00068: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00069: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00070: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00071: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00072: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00073: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00074: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00075: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00076: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00077: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00078: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00079: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00080: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00081: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00082: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00083: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00084: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00085: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00086: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00087: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00088: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00089: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00090: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00091: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00092: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00093: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00094: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00095: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00096: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00097: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00098: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00099: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00100: saving model to ../Models/rolling_nn/cp.ckpt
#
# Epoch: 100, loss:0.7549,  mae:0.6552,  mse:0.7549,  val_loss:2.1212,  val_mae:1.1506,  val_mse:2.1212,
# .
# Epoch 00101: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00102: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00103: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00104: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00105: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00106: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00107: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00108: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00109: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00110: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00111: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00112: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00113: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00114: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00115: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00116: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00117: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00118: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00119: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00120: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00121: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00122: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00123: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00124: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00125: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00126: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00127: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00128: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00129: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00130: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00131: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00132: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00133: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00134: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00135: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00136: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00137: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00138: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00139: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00140: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00141: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00142: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00143: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00144: saving model to ../Models/rolling_nn/cp.ckpt
# .
# Epoch 00145: saving model to ../Models/rolling_nn/cp.ckpt

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 140  0.667158  0.612475  0.667158  1.539614  1.000275  1.539614    140
# 141  0.660645  0.606867  0.660645  2.717961  1.355109  2.717962    141
# 142  0.660212  0.608548  0.660212  2.205092  1.193315  2.205093    142
# 143  0.664880  0.609697  0.664880  1.540289  0.987151  1.540289    143
# 144  0.656119  0.603864  0.656119  4.032949  1.689813  4.032948    144

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mae")
plt.ylim([0, 10])
plt.ylabel('MAE')
# Out:
# Text(0, 0.5, 'MAE')

# %%
plotter.plot({'Basic': history}, metric = "mse")
plt.ylim([0, 20])
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
loss, mae, mse = model.evaluate(X_test, y_test, verbose=2)
print("Loss: {}".format(loss))
print("Mean absolute error: {}".format(mae))
print("Mean squared error: {}".format(mse))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 4861/4861 - 0s - loss: 2.2509 - mae: 1.1260 - mse: 2.2509
# Loss: 2.250881081205218
# Mean absolute error: 1.1260277032852173
# Mean squared error: 2.2508809566497803

# %%
y_pred = model.predict(X_test).flatten().reshape((-1, 2))

a = plt.axes(aspect='equal')
plt.scatter(y_test.iloc[:, 0], y_pred[:, 0])
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

plt.figure()
a = plt.axes(aspect='equal')
plt.scatter(y_test.iloc[:, 1], y_pred[:, 1])
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
