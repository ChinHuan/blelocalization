# %%
from IPython.core.display import HTML, display
display(HTML("<style> .container { width: 98% !important } </style>"))
# Out:
# <style> .container { width: 98% !important } </style>

# %%
from utilities import *

import joblib
import tensorflow as tf

# %%
ble = read_ble("../Data/ble.csv")

# %%
pin = read_pin("../Data/pin.csv")

# %%
data = read_data("../Data/rssi5.csv")
data[scanners] = min_max_scaling(data[scanners])
data.fillna(0, inplace=True)
data
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
#                          time location  C400A2E19293  CD4533FFC0E1  \
# 0     2019-12-02 01:05:32.956    V1_32      0.000000           0.0
# 1     2019-12-02 01:05:32.976    V1_32      0.000000           0.0
# 2     2019-12-02 01:05:33.015    V1_32      0.000000           0.0
# 3     2019-12-02 01:05:33.034    V1_32      0.000000           0.0
# 4     2019-12-02 01:05:33.096    V1_32      0.000000           0.0
# ...                       ...      ...           ...           ...
# 49658 2019-12-12 01:47:54.481    V1_26      0.516667           0.0
# 49659 2019-12-12 01:47:54.683    V1_26      0.000000           0.0
# 49660 2019-12-12 01:47:54.736    V1_26      0.000000           0.0
# 49661 2019-12-12 01:47:54.772    V1_26      0.000000           0.0
# 49662 2019-12-12 01:47:54.796    V1_26      0.000000           0.0
#
#        D2B6503554D7  DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  \
# ...

# %%
model = tf.keras.models.load_model("../Models/Autoencoder_Simple.h5", custom_objects={'LeakyReLU': tf.keras.layers.LeakyReLU()})

# %%
encoded = model.predict(data[scanners].values)

# %%
data[scanners] = encoded

# %%
data
# Out:
#                          time location  C400A2E19293  CD4533FFC0E1  \
# 0     2019-12-02 01:05:32.956    V1_32      0.463709      0.204992
# 1     2019-12-02 01:05:32.976    V1_32      0.457026      0.206409
# 2     2019-12-02 01:05:33.015    V1_32      0.404618      0.196620
# 3     2019-12-02 01:05:33.034    V1_32      0.455935      0.206651
# 4     2019-12-02 01:05:33.096    V1_32      0.461279      0.200434
# ...                       ...      ...           ...           ...
# 49658 2019-12-12 01:47:54.481    V1_26      0.496571      0.205890
# 49659 2019-12-12 01:47:54.683    V1_26      0.470865      0.205719
# 49660 2019-12-12 01:47:54.736    V1_26      0.460379      0.201889
# 49661 2019-12-12 01:47:54.772    V1_26      0.457754      0.206248
# 49662 2019-12-12 01:47:54.796    V1_26      0.471384      0.205499
#
#        D2B6503554D7  DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  \
# 0          0.270441      0.395395      0.365936      0.179741      0.207436
# ...
