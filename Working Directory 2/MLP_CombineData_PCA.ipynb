# %%
from IPython.core.display import display, HTML
display(HTML('<style>.container { width: 98% !important }</style>'))
# Out:
# <style>.container { width: 98% !important }</style>

# %%
from utilities import *

# %%
import joblib
import tensorflow as tf
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import seaborn as sns

sns.set()

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %% [markdown]
# ## Import Data

# %%
pin = read_pin('../Data/pin.csv')
test_pin = read_pin('../Data/testPin.csv')
ble = read_ble('../Data/ble.csv')

# %%
data_1 = read_data('../Data/rssi5.csv')
data_2 = read_data('../Data/rssi_2.csv')
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all

# %%
test_1 = read_data('../Data/testRssi.csv')
test_2 = read_data('../Data/testRssi_2.csv')
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all

# %%
data = pd.concat([data_1, data_2], axis=0)
test = pd.concat([test_1, test_2], axis=0)

# %%
test.shape
# Out:
# (27229, 19)

# %% [markdown]
# ## Train Validation Split

# %%
train, validation = train_validation_split(data)

# %%
print(train.shape)
print(validation.shape)
# Out:
# (102033, 19)
# (11337, 19)

# %%
def linear_impute(data):
    for s in scanners:
        dx = data['X'] - ble[s]['X']
        dy = data['Y'] - ble[s]['Y']
        d = np.sqrt(np.square(dy) + np.square(dx))
        reg = joblib.load('../Models/linear_distance_models_2/{}.joblib'.format(s))
        ss = pd.Series(reg.predict(d.values.reshape((-1, 1))))
        data[s].fillna(ss, inplace=True)

def impute(data):
    rolling_win = 30

    data = data.sort_values("time")
    data_rolled = data.groupby("location").rolling(rolling_win, min_periods=1).mean().reset_index()
    data_imputed = data_rolled.set_index("location").groupby("location").ffill()
    data_imputed.reset_index(inplace=True)
    data_imputed["X"] = data_imputed["location"].apply(lambda x: pin[x]["X"] if x[0] == 'V' else test_pin[x]["X"])
    data_imputed["Y"] = data_imputed["location"].apply(lambda x: pin[x]["Y"] if x[0] == 'V' else test_pin[x]["Y"])
    linear_impute(data_imputed)
    return data_imputed

# %%
train_imputed = impute(train)
validation_imputed = impute(validation)
test_imputed = impute(test)

# %%
train_imputed[scanners] = normalize(train_imputed[scanners] + 100)
validation_imputed[scanners] = normalize(validation_imputed[scanners] + 100)
test_imputed[scanners] = normalize(test_imputed[scanners] + 100)

# %%
train_imputed
# Out:
#        location  level_1  C400A2E19293  CD4533FFC0E1  D2B6503554D7  \
# 0         V1_10    30171      0.270859      0.233392      0.211301
# 1         V1_10    30172      0.269998      0.232650      0.210630
# 2         V1_10    30173      0.323051      0.228668      0.207025
# 3         V1_10    30176      0.322614      0.228359      0.206745
# 4         V1_10    30177      0.323185      0.228763      0.207111
# ...         ...      ...           ...           ...           ...
# 102028     V1_9    31037      0.272912      0.159663      0.211646
# 102029     V1_9    31039      0.275097      0.160941      0.213341
# 102030     V1_9    31040      0.275097      0.140356      0.213341
# 102031     V1_9    31042      0.273806      0.139697      0.212339
# 102032     V1_9    31043      0.242039      0.139638      0.212250
#
#         DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  E43355CA8B96  \
# 0           0.353549      0.281666      0.193480      0.167370      0.284954
# 1           0.352425      0.280771      0.192865      0.184881      0.284048
# 2           0.346393      0.275966      0.189564      0.181716      0.279187
# 3           0.345925      0.275592      0.189307      0.181471      0.278809
# 4           0.346537      0.276080      0.189643      0.181792      0.279303
# ...              ...           ...           ...           ...           ...
# 102028      0.328608      0.167089      0.100253      0.222785      0.412153
# 102029      0.312151      0.168427      0.101056      0.224569      0.415453
# 102030      0.312151      0.168427      0.123513      0.224569      0.415453
# 102031      0.310686      0.167636      0.122933      0.223515      0.424679
# 102032      0.310555      0.167566      0.122882      0.223421      0.424500
#
#         ...  E8FD0B453DC4  E96AF2C858BA  EC72840D9AD3  F1307ECB3B90  \
# 0       ...      0.207280      0.113343      0.307202      0.356753
# 1       ...      0.206622      0.112983      0.306226      0.355619
# 2       ...      0.203085      0.111049      0.300985      0.349533
# 3       ...      0.202811      0.110899      0.300577      0.352859
# 4       ...      0.203170      0.111095      0.301110      0.348434
# ...     ...           ...           ...           ...           ...
# 102028  ...      0.200507      0.100253      0.306330      0.263629
# 102029  ...      0.202112      0.101056      0.308783      0.265740
# 102030  ...      0.202112      0.101056      0.310654      0.265740
# 102031  ...      0.201164      0.100582      0.309196      0.264493
# 102032  ...      0.201079      0.100539      0.309066      0.264381
#
#         F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  FDAE5980F28C         X  \
# 0           0.255005      0.218772      0.043828      0.278136  11.17660
# 1           0.254194      0.218076      0.043688      0.277252  11.17660
# 2           0.249844      0.214344      0.042941      0.272507  11.17660
# 3           0.249506      0.214054      0.042883      0.272206  11.17660
# 4           0.249948      0.214433      0.042959      0.272688  11.17660
# ...              ...           ...           ...           ...       ...
# 102028      0.303545      0.206076      0.066836      0.367595   8.17867
# 102029      0.305976      0.198370      0.067371      0.370539   8.17867
# 102030      0.305976      0.198370      0.067371      0.370539   8.17867
# 102031      0.304539      0.197438      0.067055      0.368800   8.17867
# 102032      0.331408      0.197355      0.067026      0.368645   8.17867
#
#               Y
# 0       5.29753
# 1       5.29753
# 2       5.29753
# 3       5.29753
# 4       5.29753
# ...         ...
# 102028  5.28213
# 102029  5.28213
# 102030  5.28213
# 102031  5.28213
# 102032  5.28213
#
# [102033 rows x 21 columns]

# %% [markdown]
# ## PCA

# %%
X_train_df, y_train = train_imputed[scanners].copy(), train_imputed[["X", "Y"]].values
X_validation_df, y_validation = validation_imputed[scanners].copy(), validation_imputed[["X", "Y"]].values
X_test_df, y_test = test_imputed[scanners].copy(), test_imputed[["X", "Y"]].values

# %%
components = 4

pca = PCA(n_components=components)

pca_results = pca.fit_transform(X_train_df)
for i in range(components):
    X_train_df['pca-3d-{}'.format(i + 1)] = pca_results[:, i]

pca_results = pca.transform(X_validation_df)
for i in range(components):
    X_validation_df['pca-3d-{}'.format(i + 1)] = pca_results[:, i]

pca_results = pca.transform(X_test_df)
for i in range(components):
    X_test_df['pca-3d-{}'.format(i + 1)] = pca_results[:, i]

# %%
X_train = X_train_df.values
X_validation = X_validation_df.values
X_test = X_test_df.values

# %% [markdown]
# ## Model Training

# %%
optimizer = tf.keras.optimizers.Adam(0.0001)
loss = "mse"
metrics = ["mae", "mse"]
batch_size = 32
epochs = 10000

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss')
]

inputs = tf.keras.Input(shape=(17 + components,))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(1)(x)

y = tf.keras.layers.Dense(128, activation='relu')(inputs)
y = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(1)(y)

outputs = tf.keras.layers.Concatenate(axis=1)([x, y])

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 21)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          2816        input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          2816        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           8256        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           2080        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 16)           528         dense_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            17          dense_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            17          dense_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           dense_4[0][0]
#                                                                  dense_9[0][0]
# ==================================================================================================
# Total params: 27,394
# Trainable params: 27,394
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=epochs, batch_size=batch_size, callbacks=callbacks)
# Out:
# Train on 102033 samples, validate on 11337 samples
# Epoch 1/10000
# 102033/102033 [==============================] - 4s 43us/sample - loss: 19.7421 - mae: 2.3236 - mse: 19.5045 - val_loss: 2.1710 - val_mae: 1.0718 - val_mse: 1.9611
# Epoch 2/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 1.7588 - mae: 0.9259 - mse: 1.5460 - val_loss: 1.5768 - val_mae: 0.8722 - val_mse: 1.3571
# Epoch 3/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 1.1949 - mae: 0.7189 - mse: 0.9665 - val_loss: 1.1385 - val_mae: 0.6910 - val_mse: 0.9036
# Epoch 4/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.9259 - mae: 0.5950 - mse: 0.6894 - val_loss: 1.0108 - val_mae: 0.6285 - val_mse: 0.7743
# Epoch 5/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.8009 - mae: 0.5294 - mse: 0.5659 - val_loss: 0.9233 - val_mae: 0.5886 - val_mse: 0.6901
# Epoch 6/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.7133 - mae: 0.4841 - mse: 0.4823 - val_loss: 0.8497 - val_mae: 0.5497 - val_mse: 0.6208
# Epoch 7/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.6440 - mae: 0.4478 - mse: 0.4176 - val_loss: 0.7889 - val_mae: 0.5331 - val_mse: 0.5647
# Epoch 8/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5910 - mae: 0.4193 - mse: 0.3693 - val_loss: 0.7422 - val_mae: 0.4956 - val_mse: 0.5230
# Epoch 9/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5497 - mae: 0.3975 - mse: 0.3328 - val_loss: 0.7111 - val_mae: 0.4904 - val_mse: 0.4967
# Epoch 10/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5135 - mae: 0.3765 - mse: 0.3016 - val_loss: 0.6784 - val_mae: 0.4646 - val_mse: 0.4691
# Epoch 11/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4844 - mae: 0.3602 - mse: 0.2778 - val_loss: 0.6716 - val_mae: 0.4643 - val_mse: 0.4673
# Epoch 12/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4586 - mae: 0.3446 - mse: 0.2569 - val_loss: 0.6245 - val_mae: 0.4451 - val_mse: 0.4251
# Epoch 13/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4380 - mae: 0.3326 - mse: 0.2411 - val_loss: 0.6078 - val_mae: 0.4290 - val_mse: 0.4134
# Epoch 14/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4193 - mae: 0.3214 - mse: 0.2271 - val_loss: 0.5832 - val_mae: 0.4166 - val_mse: 0.3932
# Epoch 15/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4022 - mae: 0.3112 - mse: 0.2143 - val_loss: 0.5672 - val_mae: 0.4086 - val_mse: 0.3813
# Epoch 16/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3867 - mae: 0.3013 - mse: 0.2029 - val_loss: 0.5529 - val_mae: 0.3975 - val_mse: 0.3712
# Epoch 17/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3736 - mae: 0.2934 - mse: 0.1938 - val_loss: 0.5357 - val_mae: 0.3887 - val_mse: 0.3577
# Epoch 18/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3616 - mae: 0.2863 - mse: 0.1856 - val_loss: 0.5437 - val_mae: 0.3963 - val_mse: 0.3695
# Epoch 19/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3508 - mae: 0.2803 - mse: 0.1783 - val_loss: 0.5124 - val_mae: 0.3756 - val_mse: 0.3417
# Epoch 20/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3405 - mae: 0.2731 - mse: 0.1713 - val_loss: 0.5178 - val_mae: 0.3793 - val_mse: 0.3503
# Epoch 21/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3318 - mae: 0.2681 - mse: 0.1658 - val_loss: 0.5004 - val_mae: 0.3672 - val_mse: 0.3361
# Epoch 22/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3230 - mae: 0.2628 - mse: 0.1600 - val_loss: 0.5083 - val_mae: 0.3795 - val_mse: 0.3467
# Epoch 23/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3158 - mae: 0.2583 - mse: 0.1558 - val_loss: 0.4783 - val_mae: 0.3589 - val_mse: 0.3197
# Epoch 24/10000
# 102033/102033 [==============================] - 4s 37us/sample - loss: 0.3078 - mae: 0.2529 - mse: 0.1505 - val_loss: 0.4803 - val_mae: 0.3617 - val_mse: 0.3242
# Epoch 25/10000
# 102033/102033 [==============================] - 4s 34us/sample - loss: 0.3008 - mae: 0.2489 - mse: 0.1462 - val_loss: 0.4747 - val_mae: 0.3685 - val_mse: 0.3212
# Epoch 26/10000
# 102033/102033 [==============================] - 4s 38us/sample - loss: 0.2937 - mae: 0.2435 - mse: 0.1415 - val_loss: 0.4653 - val_mae: 0.3525 - val_mse: 0.3144
# Epoch 27/10000
# 102033/102033 [==============================] - 4s 38us/sample - loss: 0.2875 - mae: 0.2397 - mse: 0.1377 - val_loss: 0.4507 - val_mae: 0.3406 - val_mse: 0.3022
# Epoch 28/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2816 - mae: 0.2358 - mse: 0.1342 - val_loss: 0.4507 - val_mae: 0.3420 - val_mse: 0.3044
# Epoch 29/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.2768 - mae: 0.2333 - mse: 0.1316 - val_loss: 0.4477 - val_mae: 0.3547 - val_mse: 0.3036
# Epoch 30/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2709 - mae: 0.2294 - mse: 0.1279 - val_loss: 0.4504 - val_mae: 0.3487 - val_mse: 0.3084
# Epoch 31/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2666 - mae: 0.2268 - mse: 0.1256 - val_loss: 0.4452 - val_mae: 0.3410 - val_mse: 0.3053
# Epoch 32/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.2626 - mae: 0.2242 - mse: 0.1237 - val_loss: 0.4319 - val_mae: 0.3358 - val_mse: 0.2940
# Epoch 33/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.2575 - mae: 0.2215 - mse: 0.1205 - val_loss: 0.4232 - val_mae: 0.3260 - val_mse: 0.2872
# Epoch 34/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.2528 - mae: 0.2178 - mse: 0.1177 - val_loss: 0.4236 - val_mae: 0.3323 - val_mse: 0.2894
# Epoch 35/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.2496 - mae: 0.2166 - mse: 0.1163 - val_loss: 0.4070 - val_mae: 0.3147 - val_mse: 0.2745
# Epoch 36/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.2449 - mae: 0.2130 - mse: 0.1133 - val_loss: 0.4069 - val_mae: 0.3139 - val_mse: 0.2762
# Epoch 37/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2412 - mae: 0.2107 - mse: 0.1114 - val_loss: 0.4055 - val_mae: 0.3154 - val_mse: 0.2765
# Epoch 38/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2382 - mae: 0.2100 - mse: 0.1100 - val_loss: 0.4002 - val_mae: 0.3181 - val_mse: 0.2727
# Epoch 39/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2342 - mae: 0.2069 - mse: 0.1075 - val_loss: 0.3959 - val_mae: 0.3118 - val_mse: 0.2700
# Epoch 40/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2300 - mae: 0.2034 - mse: 0.1049 - val_loss: 0.3910 - val_mae: 0.3028 - val_mse: 0.2668
# Epoch 41/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2275 - mae: 0.2026 - mse: 0.1040 - val_loss: 0.3870 - val_mae: 0.3033 - val_mse: 0.2643
# Epoch 42/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2234 - mae: 0.1994 - mse: 0.1013 - val_loss: 0.3850 - val_mae: 0.3033 - val_mse: 0.2637
# Epoch 43/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2207 - mae: 0.1985 - mse: 0.1001 - val_loss: 0.3982 - val_mae: 0.3149 - val_mse: 0.2784
# Epoch 44/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2174 - mae: 0.1960 - mse: 0.0983 - val_loss: 0.3698 - val_mae: 0.2956 - val_mse: 0.2514
# Epoch 45/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2145 - mae: 0.1942 - mse: 0.0967 - val_loss: 0.3827 - val_mae: 0.3130 - val_mse: 0.2656
# Epoch 46/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2115 - mae: 0.1922 - mse: 0.0951 - val_loss: 0.3784 - val_mae: 0.3057 - val_mse: 0.2625
# Epoch 47/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2087 - mae: 0.1904 - mse: 0.0934 - val_loss: 0.3941 - val_mae: 0.3265 - val_mse: 0.2795
# Epoch 48/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2060 - mae: 0.1880 - mse: 0.0920 - val_loss: 0.3651 - val_mae: 0.2954 - val_mse: 0.2517
# Epoch 49/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2035 - mae: 0.1870 - mse: 0.0907 - val_loss: 0.3681 - val_mae: 0.3025 - val_mse: 0.2559
# Epoch 50/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.2004 - mae: 0.1843 - mse: 0.0888 - val_loss: 0.3532 - val_mae: 0.2865 - val_mse: 0.2422
# Epoch 51/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1982 - mae: 0.1837 - mse: 0.0877 - val_loss: 0.3511 - val_mae: 0.2841 - val_mse: 0.2412
# Epoch 52/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1958 - mae: 0.1819 - mse: 0.0865 - val_loss: 0.3557 - val_mae: 0.2922 - val_mse: 0.2469
# Epoch 53/10000
# 102033/102033 [==============================] - 4s 37us/sample - loss: 0.1935 - mae: 0.1804 - mse: 0.0852 - val_loss: 0.3496 - val_mae: 0.2798 - val_mse: 0.2418
# Epoch 54/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1916 - mae: 0.1795 - mse: 0.0843 - val_loss: 0.3455 - val_mae: 0.2779 - val_mse: 0.2388
# Epoch 55/10000
# 102033/102033 [==============================] - 4s 34us/sample - loss: 0.1890 - mae: 0.1774 - mse: 0.0828 - val_loss: 0.3557 - val_mae: 0.2953 - val_mse: 0.2499
# Epoch 56/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1876 - mae: 0.1769 - mse: 0.0824 - val_loss: 0.3472 - val_mae: 0.2907 - val_mse: 0.2425
# Epoch 57/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1848 - mae: 0.1752 - mse: 0.0806 - val_loss: 0.3543 - val_mae: 0.2822 - val_mse: 0.2505
# Epoch 58/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1831 - mae: 0.1737 - mse: 0.0798 - val_loss: 0.3423 - val_mae: 0.2858 - val_mse: 0.2395
# Epoch 59/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1808 - mae: 0.1714 - mse: 0.0785 - val_loss: 0.3363 - val_mae: 0.2796 - val_mse: 0.2345
# Epoch 60/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1792 - mae: 0.1710 - mse: 0.0777 - val_loss: 0.3384 - val_mae: 0.2822 - val_mse: 0.2375
# Epoch 61/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1766 - mae: 0.1687 - mse: 0.0761 - val_loss: 0.3322 - val_mae: 0.2711 - val_mse: 0.2322
# Epoch 62/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1761 - mae: 0.1698 - mse: 0.0765 - val_loss: 0.3259 - val_mae: 0.2658 - val_mse: 0.2268
# Epoch 63/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1739 - mae: 0.1676 - mse: 0.0752 - val_loss: 0.3310 - val_mae: 0.2695 - val_mse: 0.2327
# Epoch 64/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1723 - mae: 0.1666 - mse: 0.0744 - val_loss: 0.3287 - val_mae: 0.2748 - val_mse: 0.2312
# Epoch 65/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1708 - mae: 0.1656 - mse: 0.0738 - val_loss: 0.3308 - val_mae: 0.2670 - val_mse: 0.2342
# Epoch 66/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1688 - mae: 0.1637 - mse: 0.0726 - val_loss: 0.3172 - val_mae: 0.2581 - val_mse: 0.2213
# Epoch 67/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1669 - mae: 0.1626 - mse: 0.0715 - val_loss: 0.3237 - val_mae: 0.2737 - val_mse: 0.2287
# Epoch 68/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1657 - mae: 0.1618 - mse: 0.0710 - val_loss: 0.3215 - val_mae: 0.2748 - val_mse: 0.2273
# Epoch 69/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1639 - mae: 0.1607 - mse: 0.0701 - val_loss: 0.3130 - val_mae: 0.2557 - val_mse: 0.2195
# Epoch 70/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1632 - mae: 0.1610 - mse: 0.0701 - val_loss: 0.3079 - val_mae: 0.2528 - val_mse: 0.2152
# Epoch 71/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1614 - mae: 0.1597 - mse: 0.0691 - val_loss: 0.3127 - val_mae: 0.2616 - val_mse: 0.2207
# Epoch 72/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1600 - mae: 0.1584 - mse: 0.0684 - val_loss: 0.3175 - val_mae: 0.2562 - val_mse: 0.2263
# Epoch 73/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1586 - mae: 0.1575 - mse: 0.0677 - val_loss: 0.3152 - val_mae: 0.2572 - val_mse: 0.2247
# Epoch 74/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1574 - mae: 0.1569 - mse: 0.0672 - val_loss: 0.3126 - val_mae: 0.2609 - val_mse: 0.2227
# Epoch 75/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1557 - mae: 0.1552 - mse: 0.0662 - val_loss: 0.3036 - val_mae: 0.2532 - val_mse: 0.2145
# Epoch 76/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1550 - mae: 0.1552 - mse: 0.0662 - val_loss: 0.3073 - val_mae: 0.2576 - val_mse: 0.2188
# Epoch 77/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1534 - mae: 0.1539 - mse: 0.0653 - val_loss: 0.3184 - val_mae: 0.2723 - val_mse: 0.2306
# Epoch 78/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1518 - mae: 0.1524 - mse: 0.0643 - val_loss: 0.2990 - val_mae: 0.2492 - val_mse: 0.2118
# Epoch 79/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1510 - mae: 0.1528 - mse: 0.0642 - val_loss: 0.2992 - val_mae: 0.2506 - val_mse: 0.2127
# Epoch 80/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1500 - mae: 0.1523 - mse: 0.0637 - val_loss: 0.2944 - val_mae: 0.2477 - val_mse: 0.2085
# Epoch 81/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1488 - mae: 0.1514 - mse: 0.0632 - val_loss: 0.2934 - val_mae: 0.2495 - val_mse: 0.2081
# Epoch 82/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1479 - mae: 0.1508 - mse: 0.0629 - val_loss: 0.3178 - val_mae: 0.2766 - val_mse: 0.2331
# Epoch 83/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1465 - mae: 0.1503 - mse: 0.0621 - val_loss: 0.3047 - val_mae: 0.2687 - val_mse: 0.2206
# Epoch 84/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1455 - mae: 0.1493 - mse: 0.0616 - val_loss: 0.3059 - val_mae: 0.2705 - val_mse: 0.2223
# Epoch 85/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1443 - mae: 0.1484 - mse: 0.0610 - val_loss: 0.2952 - val_mae: 0.2557 - val_mse: 0.2122
# Epoch 86/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1431 - mae: 0.1471 - mse: 0.0604 - val_loss: 0.3061 - val_mae: 0.2645 - val_mse: 0.2236

# %%
plt.figure()
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({"": history}, metric = "mae")
plt.ylim([0, 3])
plt.ylabel('Mean Absolute Error')

plt.figure()
plotter.plot({"": history}, metric = "mse")
plt.ylim([0, 5])
plt.ylabel('Mean Squared Error')

plt.show()

# %% [markdown]
# ## Model Validation

# %%
def inv_scale(y):
    ret_y = np.copy(y)
    ret_y[:, 0] = ret_y[:, 0] * 33.5
    ret_y[:, 1] = ret_y[:, 1] * 16.8
    return ret_y

def average_distance_error(preds, y_test, scaled=False):
    if scaled:
        preds = inv_scale(preds)
        y_test = inv_scale(y_test)
    return np.mean(np.sqrt(np.sum(np.square(preds - y_test), axis=1)))

# %%
def cdf(preds, y_test, test_data=False):
    cpin = test_pin if test_data else pin
    plt.figure(figsize=(5, 5))
    for loc in cpin.keys():
        x_selector = np.isclose(y_test[:, 0], cpin[loc]['X'], atol=0.01)
        y_selector = np.isclose(y_test[:, 1], cpin[loc]['Y'], atol=0.01)
        selector = np.logical_and(x_selector, y_selector)
        selector = selector.reshape(-1)
        Z = np.sqrt(np.sum(np.square(preds[selector] - y_test[selector]), axis=1))
        N = Z.size

        X = np.sort(Z)
        F = np.array(range(N)) / float(N)

        plt.plot(X, F, label=loc)
    plt.title('CDF of Euclidean Distance Error')
    plt.xlabel('Euclidean Distance Error (m)')
    plt.ylabel('Density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
validation_scores = model.evaluate(X_validation, y_validation, verbose=2)
print("Validation loss:", validation_scores[0])
print("Mean absolute error:", validation_scores[1])
print("Mean squared error:", validation_scores[2])

preds = model.predict(X_validation)
print("Average distance error:", average_distance_error(preds, y_validation))

fig = plt.figure(figsize=(10, 20))
lims = [0, 40]
ax1 = fig.add_subplot(121, aspect='equal', title='X', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_validation[:, 0], preds[:, 0], alpha=0.1)
ax1.plot(lims, lims)

fig = plt.figure(figsize=(10, 20))
lims = [0, 20]
ax1 = fig.add_subplot(121, aspect='equal', title='Y', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_validation[:, 1], preds[:, 1], alpha=0.1)
ax1.plot(lims, lims)

plt.show()
# Out:
# 11337/1 - 0s - loss: 0.2171 - mae: 0.2645 - mse: 0.2236
# Validation loss: 0.30607840524623453
# Mean absolute error: 0.2645418
# Mean squared error: 0.22364156
# Average distance error: 0.44437685822801243

# %%
cdf(preds, y_validation)

# %% [markdown]
# ## Model Testing

# %%
test_scores = model.evaluate(X_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Mean absolute error:", test_scores[1])
print("Mean squared error:", test_scores[2])

preds = model.predict(X_test)
print("Average distance error:", average_distance_error(preds, y_test))

fig = plt.figure(figsize=(10, 20))
lims = [0, 40]
ax1 = fig.add_subplot(121, aspect='equal', title='X', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_test[:, 0], preds[:, 0], alpha=0.1)
ax1.plot(lims, lims)

fig = plt.figure(figsize=(10, 20))
lims = [0, 20]
ax1 = fig.add_subplot(121, aspect='equal', title='Y', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')

ax1.scatter(y_test[:, 1], preds[:, 1], alpha=0.1)
ax1.plot(lims, lims)

plt.show()
# Out:
# 27229/1 - 1s - loss: 1.6171 - mae: 1.0528 - mse: 1.9033
# Test loss: 1.985726817490671
# Mean absolute error: 1.0527852
# Mean squared error: 1.9032886
# Average distance error: 1.7201218260109066

# %%
cdf(preds, y_test, test_data=True)

# %%
img =  mpimg.imread('../Map/main.png')
fingerprint_color = "r"
testdata_color = "b"
plt.figure(figsize=(40,40))
plt.imshow(img)

labels = ["V1_23", "V1_24", "V1_32", "V1_22", "V1_14", "V1_13", "V1_12", "V1_21", "V1_29", "V1_30", "V1_31", "V1_11", "V1_20", "V1_28", "V1_10", "V1_19", "V1_27", "V1_9", "V1_8", "V1_18", "V1_26"]
x = [27.151600, 29.594400, 29.689400, 23.153700, 23.169100, 20.171700, 17.173201, 18.712299, 18.691700, 23.244200, 27.133301, 14.063600, 14.159800, 14.250300, 11.176600, 10.162500, 10.141900, 8.178670, 5.180690, 6.164600, 6.255650]
y = [8.159480, 8.172020, 11.286000, 8.250140, 5.247920, 5.121330, 5.217130, 8.227330, 12.230300, 12.253700, 11.717700, 5.312350, 8.203950, 12.207500, 5.297530, 8.183420, 12.186400, 5.282130, 5.266730, 8.274090, 12.166400]
x = np.array(x) * 44
y = np.array(y) * 44

testLabels = ["T1_1", "T1_2", "T1_3", "T1_4", "T1_5", "T1_6", "T1_7", "T1_8", "T1_9", "T1_10", "T1_11", "T1_12", "T1_13", "T1_14", "T1_15", "T1_16"]
testX = [29.934250, 25.877805, 25.372470, 23.355726, 23.333564, 21.316819, 18.790348, 18.790348, 14.779021, 14.779021, 12.717952, 10.191480, 9.703916, 5.648265, 5.626103, 8.174736]
testY = [9.659024, 7.630801, 12.155781, 10.139037, 6.593112, 12.177943, 10.094712, 5.573659, 4.554205, 9.673634, 12.155781, 9.629310, 6.105547, 6.570950, 10.139037, 12.177943]
testX = np.array(testX) * 44
testY = np.array(testY) * 44

# plt.scatter(x, y, s=400, c=fingerprint_color, edgecolors="black", linewidths=3)
plt.scatter(testX, testY, s=400, c=testdata_color, edgecolors="black", linewidths=3)

# for i in range(len(labels)):
#     plt.annotate(labels[i], (x[i], y[i] - 10), fontsize=20, color=fingerprint_color, weight='bold')

for j in range(len(testLabels)):
    plt.annotate(testLabels[j], (testX[j], testY[j] - 10), fontsize=20, color=testdata_color, weight='bold')

test_all = pd.concat([X_test_df, test_imputed['location']], axis=1)
for i in range(len(testLabels)):
    loc = testLabels[i]
    test_loc = test_all[test_all['location'] == loc]
    X_loc = test_loc[scanners + ['pca-3d-{}'.format(i + 1) for i in range(components)]].values
    locs = model.predict(X_loc) * 44
    plt.scatter(locs[:, 0], locs[:, 1], alpha=0.2, label=testLabels[i])
plt.legend()
