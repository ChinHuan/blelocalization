# %%
from IPython.core.display import display, HTML
display(HTML('<style>.container { width: 98% !important }</style>'))
# Out:
# <style>.container { width: 98% !important }</style>

# %%
from utilities import *

# %%
import joblib
import tensorflow as tf
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import seaborn as sns

sns.set()

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %% [markdown]
# ## Import Data

# %%
pin = read_pin('../Data/pin.csv')
test_pin = read_pin('../Data/testPin.csv')
ble = read_ble('../Data/ble.csv')

# %%
data_1 = read_data('../Data/rssi5.csv')
data_2 = read_data('../Data/rssi_2.csv')
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all

# %%
test_1 = read_data('../Data/testRssi.csv')
test_2 = read_data('../Data/testRssi_2.csv')
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all

# %%
data = pd.concat([data_1, data_2], axis=0)
test = pd.concat([test_1, test_2], axis=0)

# %%
test.shape
# Out:
# (27229, 19)

# %% [markdown]
# ## Train Validation Split

# %%
train, validation = train_validation_split(data)

# %%
print(train.shape)
print(validation.shape)
# Out:
# (102033, 19)
# (11337, 19)

# %%
def linear_impute(data):
    for s in scanners:
        dx = data['X'] - ble[s]['X']
        dy = data['Y'] - ble[s]['Y']
        d = np.sqrt(np.square(dy) + np.square(dx))
        reg = joblib.load('../Models/linear_distance_models_2/{}.joblib'.format(s))
        ss = pd.Series(reg.predict(d.values.reshape((-1, 1))))
        data[s].fillna(ss, inplace=True)

def impute(data):
    rolling_win = 30

    data = data.sort_values("time")
    data_rolled = data.groupby("location").rolling(rolling_win, min_periods=1).mean().reset_index()
    data_imputed = data_rolled.set_index("location").groupby("location").ffill()
    data_imputed.reset_index(inplace=True)
    data_imputed["X"] = data_imputed["location"].apply(lambda x: pin[x]["X"] if x[0] == 'V' else test_pin[x]["X"])
    data_imputed["Y"] = data_imputed["location"].apply(lambda x: pin[x]["Y"] if x[0] == 'V' else test_pin[x]["Y"])
    linear_impute(data_imputed)
    return data_imputed

# %%
train_imputed = impute(train)
validation_imputed = impute(validation)
test_imputed = impute(test)

# %%
train_imputed[scanners] = normalize(train_imputed[scanners] + 100)
validation_imputed[scanners] = normalize(validation_imputed[scanners] + 100)
test_imputed[scanners] = normalize(test_imputed[scanners] + 100)

# %%
train_imputed
# Out:
#        location  level_1  C400A2E19293  CD4533FFC0E1  D2B6503554D7  \
# 0         V1_10    30171      0.270859      0.233392      0.211301
# 1         V1_10    30172      0.269998      0.232650      0.210630
# 2         V1_10    30173      0.323051      0.228668      0.207025
# 3         V1_10    30176      0.322614      0.228359      0.206745
# 4         V1_10    30177      0.323185      0.228763      0.207111
# ...         ...      ...           ...           ...           ...
# 102028     V1_9    31037      0.272912      0.159663      0.211646
# 102029     V1_9    31039      0.275097      0.160941      0.213341
# 102030     V1_9    31040      0.275097      0.140356      0.213341
# 102031     V1_9    31042      0.273806      0.139697      0.212339
# 102032     V1_9    31043      0.242039      0.139638      0.212250
#
#         DB8B36A69C56  DD697EA75B68  DF231643E227  E13B805C6CB0  E43355CA8B96  \
# 0           0.353549      0.281666      0.193480      0.167370      0.284954
# 1           0.352425      0.280771      0.192865      0.184881      0.284048
# 2           0.346393      0.275966      0.189564      0.181716      0.279187
# 3           0.345925      0.275592      0.189307      0.181471      0.278809
# 4           0.346537      0.276080      0.189643      0.181792      0.279303
# ...              ...           ...           ...           ...           ...
# 102028      0.328608      0.167089      0.100253      0.222785      0.412153
# 102029      0.312151      0.168427      0.101056      0.224569      0.415453
# 102030      0.312151      0.168427      0.123513      0.224569      0.415453
# 102031      0.310686      0.167636      0.122933      0.223515      0.424679
# 102032      0.310555      0.167566      0.122882      0.223421      0.424500
#
#         ...  E8FD0B453DC4  E96AF2C858BA  EC72840D9AD3  F1307ECB3B90  \
# 0       ...      0.207280      0.113343      0.307202      0.356753
# 1       ...      0.206622      0.112983      0.306226      0.355619
# 2       ...      0.203085      0.111049      0.300985      0.349533
# 3       ...      0.202811      0.110899      0.300577      0.352859
# 4       ...      0.203170      0.111095      0.301110      0.348434
# ...     ...           ...           ...           ...           ...
# 102028  ...      0.200507      0.100253      0.306330      0.263629
# 102029  ...      0.202112      0.101056      0.308783      0.265740
# 102030  ...      0.202112      0.101056      0.310654      0.265740
# 102031  ...      0.201164      0.100582      0.309196      0.264493
# 102032  ...      0.201079      0.100539      0.309066      0.264381
#
#         F1EDAF28E08A  F69A86823B96  FB2EE01C18CE  FDAE5980F28C         X  \
# 0           0.255005      0.218772      0.043828      0.278136  11.17660
# 1           0.254194      0.218076      0.043688      0.277252  11.17660
# 2           0.249844      0.214344      0.042941      0.272507  11.17660
# 3           0.249506      0.214054      0.042883      0.272206  11.17660
# 4           0.249948      0.214433      0.042959      0.272688  11.17660
# ...              ...           ...           ...           ...       ...
# 102028      0.303545      0.206076      0.066836      0.367595   8.17867
# 102029      0.305976      0.198370      0.067371      0.370539   8.17867
# 102030      0.305976      0.198370      0.067371      0.370539   8.17867
# 102031      0.304539      0.197438      0.067055      0.368800   8.17867
# 102032      0.331408      0.197355      0.067026      0.368645   8.17867
#
#               Y
# 0       5.29753
# 1       5.29753
# 2       5.29753
# 3       5.29753
# 4       5.29753
# ...         ...
# 102028  5.28213
# 102029  5.28213
# 102030  5.28213
# 102031  5.28213
# 102032  5.28213
#
# [102033 rows x 21 columns]

# %% [markdown]
# ## PCA

# %%
X_train_df, y_train = train_imputed[scanners].copy(), train_imputed[["X", "Y"]].values
X_validation_df, y_validation = validation_imputed[scanners].copy(), validation_imputed[["X", "Y"]].values
X_test_df, y_test = test_imputed[scanners].copy(), test_imputed[["X", "Y"]].values

# %%
components = 4

pca = PCA(n_components=components)

pca_results = pca.fit_transform(X_train_df)
for i in range(components):
    X_train_df['pca-{}'.format(i + 1)] = pca_results[:, i]

pca_results = pca.transform(X_validation_df)
for i in range(components):
    X_validation_df['pca-{}'.format(i + 1)] = pca_results[:, i]

pca_results = pca.transform(X_test_df)
for i in range(components):
    X_test_df['pca-{}'.format(i + 1)] = pca_results[:, i]

# %%
selected_scanners = scanners.copy()
selected_scanners.remove('CD4533FFC0E1')
selected_scanners.remove('EC72840D9AD3')
selected_scanners.remove('E96AF2C858BA')

new_cols = selected_scanners + ['pca-{}'.format(i + 1) for i in range(components)]

X_train = X_train_df[new_cols].values
X_validation = X_validation_df[new_cols].values
X_test = X_test_df[new_cols].values

# %% [markdown]
# ## Model Training

# %%
optimizer = tf.keras.optimizers.Adam(0.0001)
loss = "mse"
metrics = ["mae", "mse"]
batch_size = 32
epochs = 10000

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss')
]

inputs = tf.keras.Input(shape=(18,))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = tf.keras.layers.Dense(1)(x)

y = tf.keras.layers.Dense(128, activation='relu')(inputs)
y = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(y)
y = tf.keras.layers.Dense(1)(y)

outputs = tf.keras.layers.Concatenate(axis=1)([x, y])

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 18)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          2432        input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          2432        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           8256        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           2080        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 16)           528         dense_7[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            17          dense_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            17          dense_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           dense_4[0][0]
#                                                                  dense_9[0][0]
# ==================================================================================================
# Total params: 26,626
# Trainable params: 26,626
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=epochs, batch_size=batch_size, callbacks=callbacks)
# Out:
# Train on 102033 samples, validate on 11337 samples
# Epoch 1/10000
# 102033/102033 [==============================] - 4s 39us/sample - loss: 20.4984 - mae: 2.3333 - mse: 20.2548 - val_loss: 2.0425 - val_mae: 1.0284 - val_mse: 1.8242
# Epoch 2/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 1.6418 - mae: 0.8891 - mse: 1.4228 - val_loss: 1.4875 - val_mae: 0.8340 - val_mse: 1.2639
# Epoch 3/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 1.1636 - mae: 0.7077 - mse: 0.9344 - val_loss: 1.1735 - val_mae: 0.7126 - val_mse: 0.9402
# Epoch 4/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.9311 - mae: 0.6026 - mse: 0.6958 - val_loss: 1.0454 - val_mae: 0.6464 - val_mse: 0.8088
# Epoch 5/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.8029 - mae: 0.5372 - mse: 0.5665 - val_loss: 0.9285 - val_mae: 0.5966 - val_mse: 0.6926
# Epoch 6/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.7165 - mae: 0.4906 - mse: 0.4822 - val_loss: 0.8614 - val_mae: 0.5640 - val_mse: 0.6289
# Epoch 7/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.6567 - mae: 0.4583 - mse: 0.4267 - val_loss: 0.8065 - val_mae: 0.5363 - val_mse: 0.5791
# Epoch 8/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.6099 - mae: 0.4329 - mse: 0.3853 - val_loss: 0.7960 - val_mae: 0.5443 - val_mse: 0.5741
# Epoch 9/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5728 - mae: 0.4129 - mse: 0.3537 - val_loss: 0.7429 - val_mae: 0.5066 - val_mse: 0.5264
# Epoch 10/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5411 - mae: 0.3947 - mse: 0.3273 - val_loss: 0.7684 - val_mae: 0.5270 - val_mse: 0.5571
# Epoch 11/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.5133 - mae: 0.3795 - mse: 0.3045 - val_loss: 0.6852 - val_mae: 0.4773 - val_mse: 0.4789
# Epoch 12/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4891 - mae: 0.3655 - mse: 0.2851 - val_loss: 0.6564 - val_mae: 0.4631 - val_mse: 0.4548
# Epoch 13/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4670 - mae: 0.3517 - mse: 0.2677 - val_loss: 0.6427 - val_mae: 0.4546 - val_mse: 0.4456
# Epoch 14/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4477 - mae: 0.3397 - mse: 0.2527 - val_loss: 0.6205 - val_mae: 0.4391 - val_mse: 0.4277
# Epoch 15/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4312 - mae: 0.3294 - mse: 0.2405 - val_loss: 0.5995 - val_mae: 0.4273 - val_mse: 0.4108
# Epoch 16/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4174 - mae: 0.3216 - mse: 0.2306 - val_loss: 0.6070 - val_mae: 0.4399 - val_mse: 0.4221
# Epoch 17/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.4042 - mae: 0.3136 - mse: 0.2211 - val_loss: 0.5807 - val_mae: 0.4211 - val_mse: 0.3995
# Epoch 18/10000
# 102033/102033 [==============================] - 4s 37us/sample - loss: 0.3911 - mae: 0.3048 - mse: 0.2116 - val_loss: 0.5748 - val_mae: 0.4198 - val_mse: 0.3970
# Epoch 19/10000
# 102033/102033 [==============================] - 4s 36us/sample - loss: 0.3804 - mae: 0.2985 - mse: 0.2042 - val_loss: 0.5533 - val_mae: 0.4005 - val_mse: 0.3788
# Epoch 20/10000
# 102033/102033 [==============================] - 4s 39us/sample - loss: 0.3700 - mae: 0.2916 - mse: 0.1972 - val_loss: 0.5444 - val_mae: 0.3907 - val_mse: 0.3731
# Epoch 21/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.3601 - mae: 0.2849 - mse: 0.1903 - val_loss: 0.5438 - val_mae: 0.4066 - val_mse: 0.3755
# Epoch 22/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3505 - mae: 0.2784 - mse: 0.1836 - val_loss: 0.5240 - val_mae: 0.3812 - val_mse: 0.3586
# Epoch 23/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3430 - mae: 0.2742 - mse: 0.1790 - val_loss: 0.5202 - val_mae: 0.3810 - val_mse: 0.3574
# Epoch 24/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3350 - mae: 0.2686 - mse: 0.1735 - val_loss: 0.5241 - val_mae: 0.3841 - val_mse: 0.3639
# Epoch 25/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3276 - mae: 0.2633 - mse: 0.1687 - val_loss: 0.5063 - val_mae: 0.3757 - val_mse: 0.3486
# Epoch 26/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3209 - mae: 0.2599 - mse: 0.1645 - val_loss: 0.5063 - val_mae: 0.3715 - val_mse: 0.3510
# Epoch 27/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3147 - mae: 0.2558 - mse: 0.1605 - val_loss: 0.4905 - val_mae: 0.3569 - val_mse: 0.3375
# Epoch 28/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.3081 - mae: 0.2514 - mse: 0.1562 - val_loss: 0.4776 - val_mae: 0.3479 - val_mse: 0.3268
# Epoch 29/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.3027 - mae: 0.2484 - mse: 0.1530 - val_loss: 0.4739 - val_mae: 0.3535 - val_mse: 0.3252
# Epoch 30/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2979 - mae: 0.2458 - mse: 0.1502 - val_loss: 0.4696 - val_mae: 0.3469 - val_mse: 0.3228
# Epoch 31/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2924 - mae: 0.2418 - mse: 0.1466 - val_loss: 0.4613 - val_mae: 0.3412 - val_mse: 0.3165
# Epoch 32/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2878 - mae: 0.2396 - mse: 0.1440 - val_loss: 0.4634 - val_mae: 0.3453 - val_mse: 0.3204
# Epoch 33/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2824 - mae: 0.2351 - mse: 0.1403 - val_loss: 0.4507 - val_mae: 0.3303 - val_mse: 0.3096
# Epoch 34/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2783 - mae: 0.2335 - mse: 0.1381 - val_loss: 0.4560 - val_mae: 0.3453 - val_mse: 0.3167
# Epoch 35/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2735 - mae: 0.2300 - mse: 0.1350 - val_loss: 0.4488 - val_mae: 0.3361 - val_mse: 0.3111
# Epoch 36/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2700 - mae: 0.2285 - mse: 0.1332 - val_loss: 0.4340 - val_mae: 0.3219 - val_mse: 0.2980
# Epoch 37/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2656 - mae: 0.2252 - mse: 0.1304 - val_loss: 0.4390 - val_mae: 0.3345 - val_mse: 0.3046
# Epoch 38/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2627 - mae: 0.2239 - mse: 0.1290 - val_loss: 0.4355 - val_mae: 0.3259 - val_mse: 0.3025
# Epoch 39/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2592 - mae: 0.2217 - mse: 0.1270 - val_loss: 0.4294 - val_mae: 0.3189 - val_mse: 0.2979
# Epoch 40/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2556 - mae: 0.2195 - mse: 0.1248 - val_loss: 0.4206 - val_mae: 0.3152 - val_mse: 0.2904
# Epoch 41/10000
# 102033/102033 [==============================] - 4s 36us/sample - loss: 0.2520 - mae: 0.2171 - mse: 0.1226 - val_loss: 0.4165 - val_mae: 0.3091 - val_mse: 0.2876
# Epoch 42/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2483 - mae: 0.2147 - mse: 0.1201 - val_loss: 0.4162 - val_mae: 0.3214 - val_mse: 0.2887
# Epoch 43/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2453 - mae: 0.2125 - mse: 0.1184 - val_loss: 0.4104 - val_mae: 0.3077 - val_mse: 0.2841
# Epoch 44/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2425 - mae: 0.2113 - mse: 0.1170 - val_loss: 0.4162 - val_mae: 0.3105 - val_mse: 0.2912
# Epoch 45/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2397 - mae: 0.2101 - mse: 0.1154 - val_loss: 0.4175 - val_mae: 0.3358 - val_mse: 0.2937
# Epoch 46/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.2366 - mae: 0.2076 - mse: 0.1134 - val_loss: 0.3982 - val_mae: 0.3032 - val_mse: 0.2756
# Epoch 47/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2342 - mae: 0.2060 - mse: 0.1121 - val_loss: 0.3985 - val_mae: 0.2983 - val_mse: 0.2770
# Epoch 48/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2310 - mae: 0.2041 - mse: 0.1101 - val_loss: 0.3985 - val_mae: 0.3038 - val_mse: 0.2781
# Epoch 49/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2295 - mae: 0.2038 - mse: 0.1096 - val_loss: 0.3972 - val_mae: 0.3100 - val_mse: 0.2779
# Epoch 50/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2264 - mae: 0.2014 - mse: 0.1076 - val_loss: 0.3897 - val_mae: 0.2957 - val_mse: 0.2715
# Epoch 51/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2238 - mae: 0.2001 - mse: 0.1061 - val_loss: 0.3893 - val_mae: 0.3066 - val_mse: 0.2721
# Epoch 52/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2217 - mae: 0.1987 - mse: 0.1050 - val_loss: 0.3803 - val_mae: 0.2941 - val_mse: 0.2641
# Epoch 53/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2193 - mae: 0.1973 - mse: 0.1036 - val_loss: 0.3750 - val_mae: 0.2881 - val_mse: 0.2597
# Epoch 54/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2169 - mae: 0.1952 - mse: 0.1021 - val_loss: 0.3870 - val_mae: 0.3014 - val_mse: 0.2726
# Epoch 55/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2154 - mae: 0.1953 - mse: 0.1015 - val_loss: 0.3942 - val_mae: 0.3189 - val_mse: 0.2808
# Epoch 56/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2130 - mae: 0.1938 - mse: 0.1001 - val_loss: 0.3739 - val_mae: 0.2944 - val_mse: 0.2614
# Epoch 57/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2108 - mae: 0.1916 - mse: 0.0988 - val_loss: 0.3718 - val_mae: 0.2831 - val_mse: 0.2602
# Epoch 58/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2088 - mae: 0.1902 - mse: 0.0976 - val_loss: 0.3784 - val_mae: 0.2934 - val_mse: 0.2677
# Epoch 59/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2069 - mae: 0.1893 - mse: 0.0967 - val_loss: 0.3660 - val_mae: 0.2823 - val_mse: 0.2561
# Epoch 60/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2050 - mae: 0.1883 - mse: 0.0956 - val_loss: 0.3677 - val_mae: 0.2930 - val_mse: 0.2587
# Epoch 61/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2030 - mae: 0.1864 - mse: 0.0944 - val_loss: 0.3677 - val_mae: 0.2855 - val_mse: 0.2596
# Epoch 62/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.2017 - mae: 0.1863 - mse: 0.0939 - val_loss: 0.3690 - val_mae: 0.2853 - val_mse: 0.2616
# Epoch 63/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1996 - mae: 0.1847 - mse: 0.0926 - val_loss: 0.3689 - val_mae: 0.2974 - val_mse: 0.2623
# Epoch 64/10000
# 102033/102033 [==============================] - 4s 37us/sample - loss: 0.1987 - mae: 0.1853 - mse: 0.0925 - val_loss: 0.3635 - val_mae: 0.2981 - val_mse: 0.2577
# Epoch 65/10000
# 102033/102033 [==============================] - 3s 30us/sample - loss: 0.1972 - mae: 0.1841 - mse: 0.0918 - val_loss: 0.3555 - val_mae: 0.2871 - val_mse: 0.2505
# Epoch 66/10000
# 102033/102033 [==============================] - 3s 30us/sample - loss: 0.1954 - mae: 0.1827 - mse: 0.0907 - val_loss: 0.3688 - val_mae: 0.3047 - val_mse: 0.2646
# Epoch 67/10000
# 102033/102033 [==============================] - 3s 30us/sample - loss: 0.1943 - mae: 0.1831 - mse: 0.0904 - val_loss: 0.3552 - val_mae: 0.2804 - val_mse: 0.2516
# Epoch 68/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1927 - mae: 0.1815 - mse: 0.0895 - val_loss: 0.3634 - val_mae: 0.2920 - val_mse: 0.2605
# Epoch 69/10000
# 102033/102033 [==============================] - 4s 35us/sample - loss: 0.1906 - mae: 0.1794 - mse: 0.0880 - val_loss: 0.3523 - val_mae: 0.2824 - val_mse: 0.2502
# Epoch 70/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1893 - mae: 0.1788 - mse: 0.0874 - val_loss: 0.3438 - val_mae: 0.2718 - val_mse: 0.2424
# Epoch 71/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1878 - mae: 0.1781 - mse: 0.0867 - val_loss: 0.3463 - val_mae: 0.2757 - val_mse: 0.2455
# Epoch 72/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1866 - mae: 0.1779 - mse: 0.0862 - val_loss: 0.3497 - val_mae: 0.2799 - val_mse: 0.2496
# Epoch 73/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1853 - mae: 0.1772 - mse: 0.0855 - val_loss: 0.3506 - val_mae: 0.2804 - val_mse: 0.2511
# Epoch 74/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1838 - mae: 0.1756 - mse: 0.0847 - val_loss: 0.3609 - val_mae: 0.2832 - val_mse: 0.2621
# Epoch 75/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1831 - mae: 0.1759 - mse: 0.0846 - val_loss: 0.3410 - val_mae: 0.2689 - val_mse: 0.2428
# Epoch 76/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1814 - mae: 0.1743 - mse: 0.0835 - val_loss: 0.3453 - val_mae: 0.2852 - val_mse: 0.2478
# Epoch 77/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1801 - mae: 0.1737 - mse: 0.0829 - val_loss: 0.3531 - val_mae: 0.2859 - val_mse: 0.2561
# Epoch 78/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1790 - mae: 0.1729 - mse: 0.0823 - val_loss: 0.3274 - val_mae: 0.2625 - val_mse: 0.2310
# Epoch 79/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1771 - mae: 0.1711 - mse: 0.0810 - val_loss: 0.3283 - val_mae: 0.2663 - val_mse: 0.2325
# Epoch 80/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1762 - mae: 0.1710 - mse: 0.0807 - val_loss: 0.3447 - val_mae: 0.2944 - val_mse: 0.2495
# Epoch 81/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1750 - mae: 0.1704 - mse: 0.0801 - val_loss: 0.3340 - val_mae: 0.2659 - val_mse: 0.2393
# Epoch 82/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1735 - mae: 0.1683 - mse: 0.0791 - val_loss: 0.3282 - val_mae: 0.2662 - val_mse: 0.2341
# Epoch 83/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1724 - mae: 0.1685 - mse: 0.0786 - val_loss: 0.3272 - val_mae: 0.2673 - val_mse: 0.2337
# Epoch 84/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1717 - mae: 0.1685 - mse: 0.0784 - val_loss: 0.3381 - val_mae: 0.2748 - val_mse: 0.2451
# Epoch 85/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1706 - mae: 0.1678 - mse: 0.0778 - val_loss: 0.3289 - val_mae: 0.2614 - val_mse: 0.2364
# Epoch 86/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1698 - mae: 0.1671 - mse: 0.0776 - val_loss: 0.3154 - val_mae: 0.2596 - val_mse: 0.2234
# Epoch 87/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1683 - mae: 0.1657 - mse: 0.0767 - val_loss: 0.3233 - val_mae: 0.2680 - val_mse: 0.2318
# Epoch 88/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1675 - mae: 0.1654 - mse: 0.0763 - val_loss: 0.3233 - val_mae: 0.2676 - val_mse: 0.2323
# Epoch 89/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1661 - mae: 0.1641 - mse: 0.0754 - val_loss: 0.3207 - val_mae: 0.2568 - val_mse: 0.2302
# Epoch 90/10000
# 102033/102033 [==============================] - 3s 34us/sample - loss: 0.1654 - mae: 0.1646 - mse: 0.0752 - val_loss: 0.3275 - val_mae: 0.2715 - val_mse: 0.2375
# Epoch 91/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1640 - mae: 0.1630 - mse: 0.0743 - val_loss: 0.3223 - val_mae: 0.2576 - val_mse: 0.2327
# Epoch 92/10000
# 102033/102033 [==============================] - 3s 33us/sample - loss: 0.1635 - mae: 0.1633 - mse: 0.0742 - val_loss: 0.3088 - val_mae: 0.2532 - val_mse: 0.2197
# Epoch 93/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1619 - mae: 0.1613 - mse: 0.0731 - val_loss: 0.3154 - val_mae: 0.2641 - val_mse: 0.2268
# Epoch 94/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1611 - mae: 0.1609 - mse: 0.0727 - val_loss: 0.3206 - val_mae: 0.2721 - val_mse: 0.2324
# Epoch 95/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1605 - mae: 0.1609 - mse: 0.0725 - val_loss: 0.3081 - val_mae: 0.2485 - val_mse: 0.2205
# Epoch 96/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1591 - mae: 0.1598 - mse: 0.0716 - val_loss: 0.3104 - val_mae: 0.2558 - val_mse: 0.2232
# Epoch 97/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1589 - mae: 0.1600 - mse: 0.0719 - val_loss: 0.3172 - val_mae: 0.2651 - val_mse: 0.2304
# Epoch 98/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1577 - mae: 0.1594 - mse: 0.0711 - val_loss: 0.3112 - val_mae: 0.2623 - val_mse: 0.2248
# Epoch 99/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1566 - mae: 0.1580 - mse: 0.0704 - val_loss: 0.3113 - val_mae: 0.2612 - val_mse: 0.2254
# Epoch 100/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1560 - mae: 0.1582 - mse: 0.0702 - val_loss: 0.3141 - val_mae: 0.2688 - val_mse: 0.2285
# Epoch 101/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1549 - mae: 0.1570 - mse: 0.0696 - val_loss: 0.3034 - val_mae: 0.2551 - val_mse: 0.2182
# Epoch 102/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1539 - mae: 0.1558 - mse: 0.0689 - val_loss: 0.3112 - val_mae: 0.2583 - val_mse: 0.2264
# Epoch 103/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1526 - mae: 0.1550 - mse: 0.0681 - val_loss: 0.3031 - val_mae: 0.2559 - val_mse: 0.2187
# Epoch 104/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1522 - mae: 0.1554 - mse: 0.0680 - val_loss: 0.3073 - val_mae: 0.2635 - val_mse: 0.2234
# Epoch 105/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1516 - mae: 0.1550 - mse: 0.0679 - val_loss: 0.3024 - val_mae: 0.2511 - val_mse: 0.2189
# Epoch 106/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1506 - mae: 0.1542 - mse: 0.0672 - val_loss: 0.3053 - val_mae: 0.2610 - val_mse: 0.2221
# Epoch 107/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1497 - mae: 0.1532 - mse: 0.0667 - val_loss: 0.3033 - val_mae: 0.2533 - val_mse: 0.2205
# Epoch 108/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1496 - mae: 0.1541 - mse: 0.0671 - val_loss: 0.3051 - val_mae: 0.2575 - val_mse: 0.2228
# Epoch 109/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1483 - mae: 0.1529 - mse: 0.0662 - val_loss: 0.3102 - val_mae: 0.2668 - val_mse: 0.2283
# Epoch 110/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1475 - mae: 0.1522 - mse: 0.0658 - val_loss: 0.2992 - val_mae: 0.2536 - val_mse: 0.2177
# Epoch 111/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1471 - mae: 0.1521 - mse: 0.0656 - val_loss: 0.3008 - val_mae: 0.2584 - val_mse: 0.2196
# Epoch 112/10000
# 102033/102033 [==============================] - 3s 31us/sample - loss: 0.1464 - mae: 0.1522 - mse: 0.0654 - val_loss: 0.2993 - val_mae: 0.2546 - val_mse: 0.2184
# Epoch 113/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1456 - mae: 0.1512 - mse: 0.0649 - val_loss: 0.2962 - val_mae: 0.2557 - val_mse: 0.2157
# Epoch 114/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1449 - mae: 0.1514 - mse: 0.0645 - val_loss: 0.3035 - val_mae: 0.2573 - val_mse: 0.2233
# Epoch 115/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1440 - mae: 0.1502 - mse: 0.0640 - val_loss: 0.2972 - val_mae: 0.2463 - val_mse: 0.2174
# Epoch 116/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1433 - mae: 0.1501 - mse: 0.0637 - val_loss: 0.3121 - val_mae: 0.2742 - val_mse: 0.2327
# Epoch 117/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1428 - mae: 0.1494 - mse: 0.0634 - val_loss: 0.3055 - val_mae: 0.2565 - val_mse: 0.2265
# Epoch 118/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1418 - mae: 0.1484 - mse: 0.0628 - val_loss: 0.3158 - val_mae: 0.2919 - val_mse: 0.2371
# Epoch 119/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1412 - mae: 0.1483 - mse: 0.0625 - val_loss: 0.3025 - val_mae: 0.2524 - val_mse: 0.2240
# Epoch 120/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1407 - mae: 0.1482 - mse: 0.0624 - val_loss: 0.3194 - val_mae: 0.2876 - val_mse: 0.2413
# Epoch 121/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1400 - mae: 0.1475 - mse: 0.0621 - val_loss: 0.3061 - val_mae: 0.2589 - val_mse: 0.2283
# Epoch 122/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1394 - mae: 0.1471 - mse: 0.0618 - val_loss: 0.3034 - val_mae: 0.2594 - val_mse: 0.2259
# Epoch 123/10000
# 102033/102033 [==============================] - 3s 32us/sample - loss: 0.1388 - mae: 0.1472 - mse: 0.0615 - val_loss: 0.3108 - val_mae: 0.2805 - val_mse: 0.2335

# %%
plt.figure()
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({"": history}, metric = "mae")
plt.ylim([0, 3])
plt.ylabel('Mean Absolute Error')

plt.figure()
plotter.plot({"": history}, metric = "mse")
plt.ylim([0, 5])
plt.ylabel('Mean Squared Error')

plt.show()

# %% [markdown]
# ## Model Validation

# %%
def inv_scale(y):
    ret_y = np.copy(y)
    ret_y[:, 0] = ret_y[:, 0] * 33.5
    ret_y[:, 1] = ret_y[:, 1] * 16.8
    return ret_y

def average_distance_error(preds, y_test, scaled=False):
    if scaled:
        preds = inv_scale(preds)
        y_test = inv_scale(y_test)
    return np.mean(np.sqrt(np.sum(np.square(preds - y_test), axis=1)))

# %%
def cdf(preds, y_test, test_data=False):
    cpin = test_pin if test_data else pin
    plt.figure(figsize=(5, 5))
    for loc in cpin.keys():
        x_selector = np.isclose(y_test[:, 0], cpin[loc]['X'], atol=0.01)
        y_selector = np.isclose(y_test[:, 1], cpin[loc]['Y'], atol=0.01)
        selector = np.logical_and(x_selector, y_selector)
        selector = selector.reshape(-1)
        Z = np.sqrt(np.sum(np.square(preds[selector] - y_test[selector]), axis=1))
        N = Z.size

        X = np.sort(Z)
        F = np.array(range(N)) / float(N)

        plt.plot(X, F, label=loc)
    plt.title('CDF of Euclidean Distance Error')
    plt.xlabel('Euclidean Distance Error (m)')
    plt.ylabel('Density')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
validation_scores = model.evaluate(X_validation, y_validation, verbose=2)
print("Validation loss:", validation_scores[0])
print("Mean absolute error:", validation_scores[1])
print("Mean squared error:", validation_scores[2])

preds = model.predict(X_validation)
print("Average distance error:", average_distance_error(preds, y_validation))

fig = plt.figure(figsize=(10, 20))
lims = [0, 40]
ax1 = fig.add_subplot(121, aspect='equal', title='X', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_validation[:, 0], preds[:, 0], alpha=0.1)
ax1.plot(lims, lims)

fig = plt.figure(figsize=(10, 20))
lims = [0, 20]
ax1 = fig.add_subplot(121, aspect='equal', title='Y', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_validation[:, 1], preds[:, 1], alpha=0.1)
ax1.plot(lims, lims)

plt.show()
# Out:
# 11337/1 - 0s - loss: 0.2055 - mae: 0.2805 - mse: 0.2335
# Validation loss: 0.3107525443539445
# Mean absolute error: 0.2804521
# Mean squared error: 0.23351526
# Average distance error: 0.4618214125289541

# %%
cdf(preds, y_validation)

# %% [markdown]
# ## Model Testing

# %%
test_scores = model.evaluate(X_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Mean absolute error:", test_scores[1])
print("Mean squared error:", test_scores[2])

preds = model.predict(X_test)
print("Average distance error:", average_distance_error(preds, y_test))

fig = plt.figure(figsize=(10, 20))
lims = [0, 40]
ax1 = fig.add_subplot(121, aspect='equal', title='X', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')
ax1.scatter(y_test[:, 0], preds[:, 0], alpha=0.1)
ax1.plot(lims, lims)

fig = plt.figure(figsize=(10, 20))
lims = [0, 20]
ax1 = fig.add_subplot(121, aspect='equal', title='Y', xlim=lims, ylim=lims, xlabel='True Values', ylabel='Predictions')

ax1.scatter(y_test[:, 1], preds[:, 1], alpha=0.1)
ax1.plot(lims, lims)

plt.show()
# Out:
# 27229/1 - 0s - loss: 1.5674 - mae: 1.0814 - mse: 2.0242
# Test loss: 2.10146934795933
# Mean absolute error: 1.0814098
# Mean squared error: 2.0242338
# Average distance error: 1.767909856186875

# %%
cdf(preds, y_test, test_data=True)

# %%
img =  mpimg.imread('../Map/main.png')
fingerprint_color = "r"
testdata_color = "b"
plt.figure(figsize=(40,40))
plt.imshow(img)

labels = ["V1_23", "V1_24", "V1_32", "V1_22", "V1_14", "V1_13", "V1_12", "V1_21", "V1_29", "V1_30", "V1_31", "V1_11", "V1_20", "V1_28", "V1_10", "V1_19", "V1_27", "V1_9", "V1_8", "V1_18", "V1_26"]
x = [27.151600, 29.594400, 29.689400, 23.153700, 23.169100, 20.171700, 17.173201, 18.712299, 18.691700, 23.244200, 27.133301, 14.063600, 14.159800, 14.250300, 11.176600, 10.162500, 10.141900, 8.178670, 5.180690, 6.164600, 6.255650]
y = [8.159480, 8.172020, 11.286000, 8.250140, 5.247920, 5.121330, 5.217130, 8.227330, 12.230300, 12.253700, 11.717700, 5.312350, 8.203950, 12.207500, 5.297530, 8.183420, 12.186400, 5.282130, 5.266730, 8.274090, 12.166400]
x = np.array(x) * 44
y = np.array(y) * 44

testLabels = ["T1_1", "T1_2", "T1_3", "T1_4", "T1_5", "T1_6", "T1_7", "T1_8", "T1_9", "T1_10", "T1_11", "T1_12", "T1_13", "T1_14", "T1_15", "T1_16"]
testX = [29.934250, 25.877805, 25.372470, 23.355726, 23.333564, 21.316819, 18.790348, 18.790348, 14.779021, 14.779021, 12.717952, 10.191480, 9.703916, 5.648265, 5.626103, 8.174736]
testY = [9.659024, 7.630801, 12.155781, 10.139037, 6.593112, 12.177943, 10.094712, 5.573659, 4.554205, 9.673634, 12.155781, 9.629310, 6.105547, 6.570950, 10.139037, 12.177943]
testX = np.array(testX) * 44
testY = np.array(testY) * 44

# plt.scatter(x, y, s=400, c=fingerprint_color, edgecolors="black", linewidths=3)
plt.scatter(testX, testY, s=400, c=testdata_color, edgecolors="black", linewidths=3)

# for i in range(len(labels)):
#     plt.annotate(labels[i], (x[i], y[i] - 10), fontsize=20, color=fingerprint_color, weight='bold')

for j in range(len(testLabels)):
    plt.annotate(testLabels[j], (testX[j], testY[j] - 10), fontsize=20, color=testdata_color, weight='bold')

test_all = pd.concat([X_test_df, test_imputed['location']], axis=1)
for i in range(len(testLabels)):
    loc = testLabels[i]
    test_loc = test_all[test_all['location'] == loc]
    X_loc = test_loc[selected_scanners + ['pca-{}'.format(i + 1) for i in range(components)]].values
    locs = model.predict(X_loc) * 44
    plt.scatter(locs[:, 0], locs[:, 1], alpha=0.2, label=testLabels[i])
plt.legend()
