# %%
from IPython.core.display import display, HTML
display(HTML('<style>.container { width: 98% !important }</style>'))
# Out:
# <style>.container { width: 98% !important }</style>

# %%
from utilities import *

# %%
import joblib
from sklearn.preprocessing import Normalizer

# %%
pin = read_pin('../Data/pin.csv')
test_pin = read_pin('../Data/testPin.csv')
ble = read_ble('../Data/ble.csv')

# %%
data_1 = read_data('../Data/rssi5.csv')
data_2 = read_data('../Data/rssi_2.csv')
test_1 = read_data('../Data/testRssi.csv')
test_2 = read_data('../Data/testRssi_2.csv')
# Out:
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all
# All beacons: ['0117C55D14E4']
# Selecting all

# %%
d1 = data_1.groupby('location').mean()
d1
# Out:
#           C400A2E19293  CD4533FFC0E1  D2B6503554D7  DB8B36A69C56  \
# location
# V1_10       -70.054131    -82.701031    -88.851562    -66.823718
# V1_11       -82.512500    -80.140351    -76.716667    -68.814815
# V1_12       -77.567797    -69.459016    -73.988764    -73.832215
# V1_13       -82.079646    -68.726027    -81.833333    -74.631579
# V1_14       -88.777778    -67.481013    -81.865854    -79.891304
# V1_18       -80.098039    -93.575000    -89.421053    -75.435714
# V1_19       -60.263918    -82.575163    -82.941176    -70.662500
# V1_20       -71.037433    -68.893855    -72.078431    -75.893130
# V1_21       -80.852941    -66.282609    -74.349206    -78.561538
# V1_22       -86.158879    -77.874016    -78.666667    -85.432692
# V1_23       -82.863158    -73.475524    -82.382022    -82.263158
# V1_24       -90.914286    -80.223301    -85.112245    -85.901099
# V1_26       -69.444898    -85.181818    -81.892857    -75.660131
# V1_27       -69.893939    -81.346821    -73.442623    -71.683036
# V1_28       -72.381579    -76.486486    -67.161074    -82.074468
# V1_29       -85.255556    -70.128713    -71.048951    -81.235294
# V1_30       -83.156863    -76.768000    -75.657407    -87.924528
# V1_31       -90.535714    -82.414894    -86.803030    -84.855856
# V1_32       -90.096154    -80.317881    -81.194175    -86.000000
# V1_8        -80.438776    -85.400000    -85.628571    -74.297297
# V1_9        -71.243590    -78.976879    -81.316901    -63.355670
#
#           DD697EA75B68  DF231643E227  E13B805C6CB0  E43355CA8B96  \
# location
# V1_10       -73.754386    -84.063636    -85.241379    -74.541966
# V1_11       -68.000000    -77.416667    -85.224299    -76.161491
# V1_12       -72.932331    -77.052632    -82.920455    -83.206522
# V1_13       -77.795181    -74.766234    -74.974843    -79.833333
# V1_14       -80.166667    -74.442177    -64.858469    -86.918182
# V1_18       -82.055556    -88.523077    -89.382979    -64.194690
# V1_19       -68.693878    -83.715328    -86.067308    -69.565844
# V1_20       -66.681818    -75.569536    -83.638095    -78.220472
# V1_21       -68.041667    -76.075862    -72.975728    -82.525000
# V1_22       -77.221239    -66.189516    -67.584127    -91.977778
# V1_23       -76.606061    -66.229167    -74.081731    -85.033708
# V1_24       -82.971429    -72.103030    -77.182390    -82.700000
# V1_26       -76.990991    -93.526316    -86.367347    -76.915789
# V1_27       -77.460251    -88.400000    -85.186441    -76.189781
# V1_28       -65.515789    -84.991667    -80.534247    -85.310680
# F1EDAF28E08A   -2.212156
# F69A86823B96   -1.012897
# FB2EE01C18CE    0.569290
# FDAE5980F28C   -0.938207
# dtype: float64

# %%
def linear_impute(data):
    for s in scanners:
        dx = data['X'] - ble[s]['X']
        dy = data['Y'] - ble[s]['Y']
        d = np.sqrt(np.square(dy) + np.square(dx))
        reg = joblib.load('../Models/linear_distance_models_2/{}.joblib'.format(s))
        ss = pd.Series(reg.predict(d.values.reshape((-1, 1))))
        data[s].fillna(ss, inplace=True)

# %%
def impute(data, test_data=False):
    rolling_win = 30

    data = data.sort_values("time")
    data_rolled = data.groupby("location").rolling(rolling_win, min_periods=1).mean().reset_index()
    data_imputed = data_rolled.set_index("location").groupby("location").ffill()
    data_imputed.reset_index(inplace=True)
    if test_data:
        data_imputed["X"] = data_imputed["location"].apply(lambda x: test_pin[x]["X"])
        data_imputed["Y"] = data_imputed["location"].apply(lambda x: test_pin[x]["Y"])
    else:
        data_imputed["X"] = data_imputed["location"].apply(lambda x: pin[x]["X"])
        data_imputed["Y"] = data_imputed["location"].apply(lambda x: pin[x]["Y"])
    linear_impute(data_imputed)
    return data_imputed

# %%
data_1_imputed = impute(data_1)
data_2_imputed = impute(data_2)

# %%
normalizer = Normalizer()

# %%
data_1_imputed[scanners] = normalizer.transform(data_1_imputed[scanners])
data_2_imputed[scanners] = normalizer.transform(data_2_imputed[scanners])

# %%
d1_imputed = data_1_imputed.groupby('location').mean()
d2_imputed = data_2_imputed.groupby('location').mean()

# %%
(d1_imputed - d2_imputed)[scanners].mean()
# Out:
# C400A2E19293   -0.002689
# CD4533FFC0E1   -0.002039
# D2B6503554D7   -0.003350
# DB8B36A69C56   -0.004427
# DD697EA75B68   -0.001275
# DF231643E227   -0.001674
# E13B805C6CB0    0.003199
# E43355CA8B96   -0.003919
# E6D9D20DD197    0.029791
# E8FD0B453DC4    0.003080
# E96AF2C858BA   -0.007737
# EC72840D9AD3    0.004498
# F1307ECB3B90   -0.000166
# F1EDAF28E08A   -0.018903
# F69A86823B96   -0.000064
# FB2EE01C18CE    0.013118
# FDAE5980F28C   -0.000802
# dtype: float64

# %%
test_1_imputed = impute(test_1, test_data=True)
test_2_imputed = impute(test_2, test_data=True)

# %%
normalizer = Normalizer()

# %%
test_1_imputed[scanners] = normalizer.transform(test_1_imputed[scanners])
test_2_imputed[scanners] = normalizer.transform(test_2_imputed[scanners])

# %%
t1_imputed = test_1_imputed.groupby('location').mean()
t2_imputed = test_2_imputed.groupby('location').mean()

# %%
(t1_imputed - t2_imputed)[scanners].mean()
# Out:
# C400A2E19293    0.001136
# CD4533FFC0E1   -0.005627
# D2B6503554D7    0.002540
# DB8B36A69C56   -0.004907
# DD697EA75B68    0.008753
# DF231643E227    0.001121
# E13B805C6CB0    0.000147
# E43355CA8B96    0.013964
# E6D9D20DD197    0.008826
# E8FD0B453DC4    0.016388
# E96AF2C858BA   -0.006577
# EC72840D9AD3   -0.004208
# F1307ECB3B90   -0.002334
# F1EDAF28E08A    0.016767
# F69A86823B96    0.000787
# FB2EE01C18CE    0.045914
# FDAE5980F28C   -0.013372
# dtype: float64
